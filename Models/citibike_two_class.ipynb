# %% [markdown]
# # Test against just two classes
#
# In this notebook we will take in our data from CitiBike and organize down to just one start station and two end neighborhoods. The goal is to test if we can better predict on a question with fewer target classes.
#
# To do this we will test the Xgboost classifier and use the same variables we have for other trials.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, r2_score, mean_squared_error
from sklearn.model_selection import GridSearchCV
import itertools
import matplotlib.pyplot as plt
from citibike_scripts_derrick import show_cf
# %matplotlib inline

# %% [markdown]
# Create a DF with neighborhoods connected to Stations.

# %%
neighborhoods = pd.read_csv('citibike_data/citibike_neighborhoods.csv')

# %%
neighborhoods['end station name'] = neighborhoods['stops']
neighborhoods = neighborhoods[['end station name', 'stop_nhbr']]

# %% [markdown]
# ### Import and Pull only data from a single station start and two destinations.

# %%
for i in range(1,13):
    if i == 1:
        big = pd.read_csv('citibike_data/2018'+ str(i).zfill(2)+'-citibike-tripdata.csv')
        big = pd.merge(big, neighborhoods, on='end station name', how='left')
        big = big[(big['start station id']==490) & ((big['stop_nhbr']=='Upper West Side') 
       |(big['stop_nhbr']=='East Village'))]
        #big = big.sample(frac=.1)
    else:
        temp = pd.read_csv('citibike_data/2018'+ str(i).zfill(2)+'-citibike-tripdata.csv')
        temp = pd.merge(temp, neighborhoods, on='end station name', how='left')
        temp = temp[(temp['start station id']==490) & ((temp['stop_nhbr']=='Upper West Side') 
       |(temp['stop_nhbr']=='East Village'))]
        big = pd.concat([big, temp])

# %%
big = big.dropna()

# %%
big.usertype = pd.Categorical(big.usertype)
big.usertype = big.usertype.cat.codes

# %%
big['starttime'] = pd.to_datetime(big['starttime'])
big['start_month'] = big.starttime.dt.month
big['start_day_of_week'] = big.starttime.dt.dayofweek
big['start_hour'] = big.starttime.dt.hour
big['start_date'] = big.starttime.dt.day

big['starttime'] = big.starttime.dt.date
big['starttime'] = pd.to_datetime(big['starttime'])

# %%
weather_df = pd.read_csv('citibike_data/2018_weather.csv')
weather_df['starttime'] = pd.to_datetime(weather_df['date'])
weather_df = weather_df.drop(['max_temp', 'min_temp','departure', 'Hdd', 'cdd', 'new_snow', 'date' ], axis=1)

# %%
big = pd.merge(big, weather_df, on='starttime', how='left')

# %%
big = big.drop(['tripduration','starttime', 'stoptime','start station name',
                'end station id', 'bikeid', 'start station latitude', 
                'start station longitude', 'end station latitude', 
                'end station longitude','end station name', 'start_date'], axis=1)

# %%
df2=big

# %% [markdown]
# Split variables from targets:

# %%
labels = df2.stop_nhbr

# %%
labels_removed_df = df2.drop('stop_nhbr', axis=1)

# %% [markdown]
# Scale data:

# %%
scaler = MinMaxScaler()
scaled_df = scaler.fit_transform(labels_removed_df.astype(float))

# %% [markdown]
# Split data into training and testing sets. Maintain at least some of each target class in both sets with the 'stratify' argument.

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_df, labels)

# %% [markdown]
# Fit xgboost model:

# %%
clf = xgb.XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
       colsample_bytree=1, gamma=0, learning_rate=0.7, max_delta_step=0,
       max_depth=4, min_child_weight=5, missing=None, n_estimators=300,
       n_jobs=1, nthread=None, objective='binary:logistic', random_state=42,
       reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
       silent=True, subsample=1)

# %%
clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.7, max_delta_step=0,
#        max_depth=4, min_child_weight=5, missing=None, n_estimators=300,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)

# %%
training_preds = clf.predict(X_train)

# %%
val_preds = clf.predict(X_test)
training_accuracy = accuracy_score(y_train, training_preds)
val_accuracy = accuracy_score(y_test, val_preds)

print("Training Accuracy: {:.4}%".format(training_accuracy * 100))
print("Validation accuracy: {:.4}%".format(val_accuracy * 100))
# Out:
# Training Accuracy: 86.19%
# Validation accuracy: 65.4%

# %%
show_cf(y_test, val_preds)

# %%
param_grid = {
    "learning_rate": [0.5, 0.7, 0.1],
    'max_depth': [2, 3, 4],
    'min_child_weight': [4, 5],
    'n_estimators': [300, 400, 500],
}

# %%
grid_clf = GridSearchCV(clf, param_grid, scoring='accuracy', cv=None, n_jobs=1)
eval_metric = ["auc", 'error']
eval_set = [(X_train, y_train), (X_test, y_test)]
grid_clf.fit(X_train, y_train, eval_set= eval_set, early_stopping_rounds=20)
best_parameters = grid_clf.best_params_

print("Grid Search found the following optimal parameters: ")
for param_name in sorted(best_parameters.keys()):
    print("%s: %r" % (param_name, best_parameters[param_name]))

training_preds = grid_clf.predict(X_train)
val_preds = grid_clf.predict(X_test)
training_accuracy = accuracy_score(y_train, training_preds)
val_accuracy = accuracy_score(y_test, val_preds)

print("")
print("Training Accuracy: {:.4}%".format(training_accuracy * 100))
print("Validation accuracy: {:.4}%".format(val_accuracy * 100))
# Out:
# [0]	validation_0-error:0.428763	validation_1-error:0.409091
# Multiple eval metrics have been passed: 'validation_1-error' will be used for early stopping.
#
# Will train until validation_1-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.423387	validation_1-error:0.421554
# [2]	validation_0-error:0.4174	validation_1-error:0.417522
# [3]	validation_0-error:0.400782	validation_1-error:0.393695
# [4]	validation_0-error:0.40176	validation_1-error:0.393328
# [5]	validation_0-error:0.401515	validation_1-error:0.398827
# [6]	validation_0-error:0.400415	validation_1-error:0.395161
# [7]	validation_0-error:0.40066	validation_1-error:0.396994
# [8]	validation_0-error:0.398827	validation_1-error:0.395528
# [9]	validation_0-error:0.396383	validation_1-error:0.395161
# [10]	validation_0-error:0.395039	validation_1-error:0.395528
# [11]	validation_0-error:0.394917	validation_1-error:0.392229
# [12]	validation_0-error:0.392595	validation_1-error:0.393328
# [13]	validation_0-error:0.387341	validation_1-error:0.396628
# [14]	validation_0-error:0.38563	validation_1-error:0.394428
# [15]	validation_0-error:0.385142	validation_1-error:0.396261
# [16]	validation_0-error:0.385264	validation_1-error:0.384164
# [17]	validation_0-error:0.383798	validation_1-error:0.385997
# [18]	validation_0-error:0.378788	validation_1-error:0.377199
# [19]	validation_0-error:0.375978	validation_1-error:0.374633
# [20]	validation_0-error:0.377688	validation_1-error:0.378666
# [21]	validation_0-error:0.378421	validation_1-error:0.378299
# [22]	validation_0-error:0.378543	validation_1-error:0.378299
# [23]	validation_0-error:0.37891	validation_1-error:0.383065
# [24]	validation_0-error:0.377444	validation_1-error:0.380499
# [25]	validation_0-error:0.376222	validation_1-error:0.376833
# [26]	validation_0-error:0.373778	validation_1-error:0.3761
# [27]	validation_0-error:0.375489	validation_1-error:0.379399
# [28]	validation_0-error:0.3739	validation_1-error:0.380865
# [29]	validation_0-error:0.373167	validation_1-error:0.383798
# [30]	validation_0-error:0.372067	validation_1-error:0.384531
# [31]	validation_0-error:0.372434	validation_1-error:0.381232
# [32]	validation_0-error:0.371701	validation_1-error:0.384897
# [33]	validation_0-error:0.371823	validation_1-error:0.383431
# [34]	validation_0-error:0.370968	validation_1-error:0.381965
# [35]	validation_0-error:0.37219	validation_1-error:0.384164
# [36]	validation_0-error:0.371334	validation_1-error:0.380499
# [37]	validation_0-error:0.369135	validation_1-error:0.379765
# [38]	validation_0-error:0.367791	validation_1-error:0.378666
# [39]	validation_0-error:0.365714	validation_1-error:0.372434
# [40]	validation_0-error:0.36498	validation_1-error:0.371701
# [41]	validation_0-error:0.365469	validation_1-error:0.3739
# [42]	validation_0-error:0.36498	validation_1-error:0.372434
# [43]	validation_0-error:0.36327	validation_1-error:0.371701
# [44]	validation_0-error:0.363759	validation_1-error:0.371701
# [45]	validation_0-error:0.364125	validation_1-error:0.371701
# [46]	validation_0-error:0.362537	validation_1-error:0.372801
# [47]	validation_0-error:0.359971	validation_1-error:0.371334
# [48]	validation_0-error:0.357893	validation_1-error:0.370235
# [49]	validation_0-error:0.358016	validation_1-error:0.370968
# [50]	validation_0-error:0.357649	validation_1-error:0.369868
# [51]	validation_0-error:0.358138	validation_1-error:0.367669
# [52]	validation_0-error:0.356549	validation_1-error:0.368768
# [53]	validation_0-error:0.356427	validation_1-error:0.369868
# [54]	validation_0-error:0.356183	validation_1-error:0.370968
# [55]	validation_0-error:0.356672	validation_1-error:0.371701
# /anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [56]	validation_0-error:0.356916	validation_1-error:0.371701
# [57]	validation_0-error:0.356061	validation_1-error:0.369135
# [58]	validation_0-error:0.355327	validation_1-error:0.372434
# [59]	validation_0-error:0.355327	validation_1-error:0.373167
# [60]	validation_0-error:0.356549	validation_1-error:0.374633
# [61]	validation_0-error:0.356183	validation_1-error:0.373167
# [62]	validation_0-error:0.35716	validation_1-error:0.3739
# [63]	validation_0-error:0.354717	validation_1-error:0.374267
# [64]	validation_0-error:0.355572	validation_1-error:0.374267
# [65]	validation_0-error:0.355205	validation_1-error:0.375
# [66]	validation_0-error:0.355938	validation_1-error:0.370968
# [67]	validation_0-error:0.35716	validation_1-error:0.3739
# [68]	validation_0-error:0.356183	validation_1-error:0.374633
# [69]	validation_0-error:0.355694	validation_1-error:0.373534
# [70]	validation_0-error:0.351173	validation_1-error:0.375367
# [71]	validation_0-error:0.351906	validation_1-error:0.375
# Stopping. Best iteration:
# [51]	validation_0-error:0.358138	validation_1-error:0.367669
#
# [0]	validation_0-error:0.428886	validation_1-error:0.41239
# Multiple eval metrics have been passed: 'validation_1-error' will be used for early stopping.
#
# Will train until validation_1-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.431696	validation_1-error:0.416422
# [2]	validation_0-error:0.413978	validation_1-error:0.408358
# [3]	validation_0-error:0.409702	validation_1-error:0.403592
# [4]	validation_0-error:0.41239	validation_1-error:0.407258
# [5]	validation_0-error:0.411168	validation_1-error:0.406158
# [6]	validation_0-error:0.413856	validation_1-error:0.414223
# [7]	validation_0-error:0.408969	validation_1-error:0.405425
# [8]	validation_0-error:0.406281	validation_1-error:0.40176
# [9]	validation_0-error:0.405059	validation_1-error:0.396628
# [10]	validation_0-error:0.397116	validation_1-error:0.398827
# [11]	validation_0-error:0.393084	validation_1-error:0.393328
# [12]	validation_0-error:0.396872	validation_1-error:0.39956
# [13]	validation_0-error:0.390152	validation_1-error:0.398827
# [14]	validation_0-error:0.380499	validation_1-error:0.385997
# [15]	validation_0-error:0.381109	validation_1-error:0.394062
# [16]	validation_0-error:0.381354	validation_1-error:0.392595
# [17]	validation_0-error:0.380132	validation_1-error:0.38673
# [18]	validation_0-error:0.377199	validation_1-error:0.377566
# [19]	validation_0-error:0.374633	validation_1-error:0.3739
# [20]	validation_0-error:0.373412	validation_1-error:0.374633
# [21]	validation_0-error:0.37109	validation_1-error:0.376833
# [22]	validation_0-error:0.371212	validation_1-error:0.375733
# [23]	validation_0-error:0.369868	validation_1-error:0.382698
# [24]	validation_0-error:0.366202	validation_1-error:0.378299
# [25]	validation_0-error:0.364736	validation_1-error:0.375367
# [26]	validation_0-error:0.365836	validation_1-error:0.3739
# [27]	validation_0-error:0.365469	validation_1-error:0.373167
# [28]	validation_0-error:0.364614	validation_1-error:0.372434
# [29]	validation_0-error:0.36217	validation_1-error:0.374633
# [30]	validation_0-error:0.362781	validation_1-error:0.373534
# [31]	validation_0-error:0.360215	validation_1-error:0.375
# [32]	validation_0-error:0.35826	validation_1-error:0.373167
# [33]	validation_0-error:0.360826	validation_1-error:0.375
# [34]	validation_0-error:0.358016	validation_1-error:0.373534
# [35]	validation_0-error:0.356549	validation_1-error:0.371334
# [36]	validation_0-error:0.355938	validation_1-error:0.370235
# [37]	validation_0-error:0.356183	validation_1-error:0.368402
# [38]	validation_0-error:0.35545	validation_1-error:0.368402
# [39]	validation_0-error:0.354717	validation_1-error:0.367302
# [40]	validation_0-error:0.353861	validation_1-error:0.367669
# [41]	validation_0-error:0.354106	validation_1-error:0.363636
# [42]	validation_0-error:0.354594	validation_1-error:0.364736
# [43]	validation_0-error:0.354839	validation_1-error:0.368402
# [44]	validation_0-error:0.354472	validation_1-error:0.368035
# [45]	validation_0-error:0.354228	validation_1-error:0.368402
# [46]	validation_0-error:0.354472	validation_1-error:0.367669
# [47]	validation_0-error:0.357405	validation_1-error:0.365469
# [48]	validation_0-error:0.357282	validation_1-error:0.369868
# [49]	validation_0-error:0.356672	validation_1-error:0.368402
# [50]	validation_0-error:0.355327	validation_1-error:0.368035
# [51]	validation_0-error:0.351662	validation_1-error:0.366569
# [52]	validation_0-error:0.349585	validation_1-error:0.365469
# [53]	validation_0-error:0.34824	validation_1-error:0.365469
# [54]	validation_0-error:0.348729	validation_1-error:0.366202
# [55]	validation_0-error:0.348485	validation_1-error:0.365836
# [56]	validation_0-error:0.346896	validation_1-error:0.367302
# [57]	validation_0-error:0.351417	validation_1-error:0.372067
# [58]	validation_0-error:0.352395	validation_1-error:0.373534
# [59]	validation_0-error:0.35154	validation_1-error:0.367302
# [60]	validation_0-error:0.352761	validation_1-error:0.366202
# [61]	validation_0-error:0.351906	validation_1-error:0.367669
# Stopping. Best iteration:
# [41]	validation_0-error:0.354106	validation_1-error:0.363636
#
# [0]	validation_0-error:0.430108	validation_1-error:0.430352
# Multiple eval metrics have been passed: 'validation_1-error' will be used for early stopping.
#
# Will train until validation_1-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.424976	validation_1-error:0.42412
# [2]	validation_0-error:0.419966	validation_1-error:0.420821
# [3]	validation_0-error:0.421676	validation_1-error:0.420088
# [4]	validation_0-error:0.422043	validation_1-error:0.420821
# [5]	validation_0-error:0.413612	validation_1-error:0.413123
# [6]	validation_0-error:0.394673	validation_1-error:0.387463
# [7]	validation_0-error:0.392351	validation_1-error:0.38893
# [8]	validation_0-error:0.392718	validation_1-error:0.387463
# [9]	validation_0-error:0.389418	validation_1-error:0.382331
# [10]	validation_0-error:0.391007	validation_1-error:0.388196
# [11]	validation_0-error:0.388196	validation_1-error:0.388196
# [12]	validation_0-error:0.378055	validation_1-error:0.378299
# [13]	validation_0-error:0.377077	validation_1-error:0.375367
# [14]	validation_0-error:0.375733	validation_1-error:0.375733
# [15]	validation_0-error:0.373534	validation_1-error:0.377566
# [16]	validation_0-error:0.372923	validation_1-error:0.379399
# [17]	validation_0-error:0.37219	validation_1-error:0.380865
# [18]	validation_0-error:0.37109	validation_1-error:0.383065
# [19]	validation_0-error:0.371701	validation_1-error:0.387097
# [20]	validation_0-error:0.370601	validation_1-error:0.384531
# [21]	validation_0-error:0.370357	validation_1-error:0.384164
# [22]	validation_0-error:0.36999	validation_1-error:0.382698
# [23]	validation_0-error:0.370112	validation_1-error:0.381965
# [24]	validation_0-error:0.367302	validation_1-error:0.382331
# [25]	validation_0-error:0.364492	validation_1-error:0.387097
# [26]	validation_0-error:0.361804	validation_1-error:0.385264
# [27]	validation_0-error:0.360215	validation_1-error:0.380865
# [28]	validation_0-error:0.359971	validation_1-error:0.379032
# [29]	validation_0-error:0.359971	validation_1-error:0.379032
# [30]	validation_0-error:0.359726	validation_1-error:0.377933
# [31]	validation_0-error:0.358382	validation_1-error:0.380132
# [32]	validation_0-error:0.357893	validation_1-error:0.382698
# [33]	validation_0-error:0.358993	validation_1-error:0.382331
# Stopping. Best iteration:
# [13]	validation_0-error:0.377077	validation_1-error:0.375367
#
# [0]	validation_0-error:0.428763	validation_1-error:0.409091
# Multiple eval metrics have been passed: 'validation_1-error' will be used for early stopping.
#
# Will train until validation_1-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.423387	validation_1-error:0.421554
# [2]	validation_0-error:0.4174	validation_1-error:0.417522
# [3]	validation_0-error:0.400782	validation_1-error:0.393695
# [4]	validation_0-error:0.40176	validation_1-error:0.393328
# [5]	validation_0-error:0.401515	validation_1-error:0.398827
# [6]	validation_0-error:0.400415	validation_1-error:0.395161
# [7]	validation_0-error:0.40066	validation_1-error:0.396994
# [8]	validation_0-error:0.398827	validation_1-error:0.395528
# [9]	validation_0-error:0.396383	validation_1-error:0.395161
# [10]	validation_0-error:0.395039	validation_1-error:0.395528
# [11]	validation_0-error:0.394917	validation_1-error:0.392229
# [12]	validation_0-error:0.392595	validation_1-error:0.393328
# [13]	validation_0-error:0.387341	validation_1-error:0.396628
# [14]	validation_0-error:0.38563	validation_1-error:0.394428
# [15]	validation_0-error:0.385142	validation_1-error:0.396261
# [16]	validation_0-error:0.385264	validation_1-error:0.384164
# [17]	validation_0-error:0.383798	validation_1-error:0.385997
# [18]	validation_0-error:0.378788	validation_1-error:0.377199
# [19]	validation_0-error:0.375978	validation_1-error:0.374633
# [20]	validation_0-error:0.377688	validation_1-error:0.378666
# [21]	validation_0-error:0.378421	validation_1-error:0.378299
# [22]	validation_0-error:0.378543	validation_1-error:0.378299
# [23]	validation_0-error:0.37891	validation_1-error:0.383065
# [24]	validation_0-error:0.377444	validation_1-error:0.380499
# [25]	validation_0-error:0.376222	validation_1-error:0.376833
# [26]	validation_0-error:0.373778	validation_1-error:0.3761
# [27]	validation_0-error:0.375489	validation_1-error:0.379399
# [28]	validation_0-error:0.3739	validation_1-error:0.380865
# [29]	validation_0-error:0.373167	validation_1-error:0.383798
# [30]	validation_0-error:0.372067	validation_1-error:0.384531
# [31]	validation_0-error:0.372434	validation_1-error:0.381232
# [32]	validation_0-error:0.371701	validation_1-error:0.384897
# [33]	validation_0-error:0.371823	validation_1-error:0.383431
# [34]	validation_0-error:0.370968	validation_1-error:0.381965
# [35]	validation_0-error:0.37219	validation_1-error:0.384164
# [36]	validation_0-error:0.371334	validation_1-error:0.380499
# [37]	validation_0-error:0.369135	validation_1-error:0.379765
# [38]	validation_0-error:0.367791	validation_1-error:0.378666
# [39]	validation_0-error:0.365714	validation_1-error:0.372434
# [40]	validation_0-error:0.36498	validation_1-error:0.371701
# [41]	validation_0-error:0.365469	validation_1-error:0.3739
# [42]	validation_0-error:0.36498	validation_1-error:0.372434
# [43]	validation_0-error:0.36327	validation_1-error:0.371701
# [44]	validation_0-error:0.363759	validation_1-error:0.371701
# [45]	validation_0-error:0.364125	validation_1-error:0.371701
# [46]	validation_0-error:0.362537	validation_1-error:0.372801
# [47]	validation_0-error:0.359971	validation_1-error:0.371334
# [48]	validation_0-error:0.357893	validation_1-error:0.370235
# [49]	validation_0-error:0.358016	validation_1-error:0.370968
# [50]	validation_0-error:0.357649	validation_1-error:0.369868
# [51]	validation_0-error:0.358138	validation_1-error:0.367669
# [52]	validation_0-error:0.356549	validation_1-error:0.368768
# [53]	validation_0-error:0.356427	validation_1-error:0.369868
# [54]	validation_0-error:0.356183	validation_1-error:0.370968
# [55]	validation_0-error:0.356672	validation_1-error:0.371701
# [56]	validation_0-error:0.356916	validation_1-error:0.371701
# [57]	validation_0-error:0.356061	validation_1-error:0.369135
# [58]	validation_0-error:0.355327	validation_1-error:0.372434
# [59]	validation_0-error:0.355327	validation_1-error:0.373167
# [60]	validation_0-error:0.356549	validation_1-error:0.374633
# [61]	validation_0-error:0.356183	validation_1-error:0.373167
# [62]	validation_0-error:0.35716	validation_1-error:0.3739
# [63]	validation_0-error:0.354717	validation_1-error:0.374267
# [64]	validation_0-error:0.355572	validation_1-error:0.374267
# [65]	validation_0-error:0.355205	validation_1-error:0.375
# [66]	validation_0-error:0.355938	validation_1-error:0.370968
# [67]	validation_0-error:0.35716	validation_1-error:0.3739
# [68]	validation_0-error:0.356183	validation_1-error:0.374633
# [69]	validation_0-error:0.355694	validation_1-error:0.373534
# [70]	validation_0-error:0.351173	validation_1-error:0.375367
# [71]	validation_0-error:0.351906	validation_1-error:0.375
# Stopping. Best iteration:
# [51]	validation_0-error:0.358138	validation_1-error:0.367669
#
# [0]	validation_0-error:0.428886	validation_1-error:0.41239
# Multiple eval metrics have been passed: 'validation_1-error' will be used for early stopping.
#
# Will train until validation_1-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.431696	validation_1-error:0.416422
# [2]	validation_0-error:0.413978	validation_1-error:0.408358
# [3]	validation_0-error:0.409702	validation_1-error:0.403592
# [4]	validation_0-error:0.41239	validation_1-error:0.407258
# [5]	validation_0-error:0.411168	validation_1-error:0.406158
# [6]	validation_0-error:0.413856	validation_1-error:0.414223
# [7]	validation_0-error:0.408969	validation_1-error:0.405425
# [8]	validation_0-error:0.406281	validation_1-error:0.40176
# [9]	validation_0-error:0.405059	validation_1-error:0.396628
# [10]	validation_0-error:0.397116	validation_1-error:0.398827
# [11]	validation_0-error:0.393084	validation_1-error:0.393328
# [12]	validation_0-error:0.396872	validation_1-error:0.39956
# [13]	validation_0-error:0.390152	validation_1-error:0.398827
# [14]	validation_0-error:0.380499	validation_1-error:0.385997
# [15]	validation_0-error:0.381109	validation_1-error:0.394062
# [16]	validation_0-error:0.381354	validation_1-error:0.392595
# [17]	validation_0-error:0.380132	validation_1-error:0.38673
# [18]	validation_0-error:0.377199	validation_1-error:0.377566
# [19]	validation_0-error:0.374633	validation_1-error:0.3739
# [20]	validation_0-error:0.373412	validation_1-error:0.374633
# [21]	validation_0-error:0.37109	validation_1-error:0.376833
# [22]	validation_0-error:0.371212	validation_1-error:0.375733
# [23]	validation_0-error:0.369868	validation_1-error:0.382698
# [24]	validation_0-error:0.366202	validation_1-error:0.378299
# [25]	validation_0-error:0.364736	validation_1-error:0.375367
# [26]	validation_0-error:0.365836	validation_1-error:0.3739
# [27]	validation_0-error:0.365469	validation_1-error:0.373167
# [28]	validation_0-error:0.364614	validation_1-error:0.372434
# [29]	validation_0-error:0.36217	validation_1-error:0.374633
# [30]	validation_0-error:0.362781	validation_1-error:0.373534
# [31]	validation_0-error:0.360215	validation_1-error:0.375
# [32]	validation_0-error:0.35826	validation_1-error:0.373167
# [33]	validation_0-error:0.360826	validation_1-error:0.375
# [34]	validation_0-error:0.358016	validation_1-error:0.373534
# [35]	validation_0-error:0.356549	validation_1-error:0.371334
# [36]	validation_0-error:0.355938	validation_1-error:0.370235
# [37]	validation_0-error:0.356183	validation_1-error:0.368402
# [38]	validation_0-error:0.35545	validation_1-error:0.368402
# [39]	validation_0-error:0.354717	validation_1-error:0.367302
# [40]	validation_0-error:0.353861	validation_1-error:0.367669
# [41]	validation_0-error:0.354106	validation_1-error:0.363636
# [42]	validation_0-error:0.354594	validation_1-error:0.364736
# [43]	validation_0-error:0.354839	validation_1-error:0.368402
# [44]	validation_0-error:0.354472	validation_1-error:0.368035
# [45]	validation_0-error:0.354228	validation_1-error:0.368402
# [46]	validation_0-error:0.354472	validation_1-error:0.367669
# [47]	validation_0-error:0.357405	validation_1-error:0.365469
# [48]	validation_0-error:0.357282	validation_1-error:0.369868
# [49]	validation_0-error:0.356672	validation_1-error:0.368402
# [50]	validation_0-error:0.355327	validation_1-error:0.368035
# [51]	validation_0-error:0.351662	validation_1-error:0.366569
# [52]	validation_0-error:0.349585	validation_1-error:0.365469
# [53]	validation_0-error:0.34824	validation_1-error:0.365469
# [54]	validation_0-error:0.348729	validation_1-error:0.366202
# [55]	validation_0-error:0.348485	validation_1-error:0.365836
# [56]	validation_0-error:0.346896	validation_1-error:0.367302
# [57]	validation_0-error:0.351417	validation_1-error:0.372067
# [58]	validation_0-error:0.352395	validation_1-error:0.373534
# [59]	validation_0-error:0.35154	validation_1-error:0.367302
# [60]	validation_0-error:0.352761	validation_1-error:0.366202
# [61]	validation_0-error:0.351906	validation_1-error:0.367669
# Stopping. Best iteration:
# [41]	validation_0-error:0.354106	validation_1-error:0.363636
#
# [0]	validation_0-error:0.430108	validation_1-error:0.430352
# Multiple eval metrics have been passed: 'validation_1-error' will be used for early stopping.
#
# Will train until validation_1-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.424976	validation_1-error:0.42412
# [2]	validation_0-error:0.419966	validation_1-error:0.420821
# [3]	validation_0-error:0.421676	validation_1-error:0.420088
# [4]	validation_0-error:0.422043	validation_1-error:0.420821
# [5]	validation_0-error:0.413612	validation_1-error:0.413123
# [6]	validation_0-error:0.394673	validation_1-error:0.387463
# [7]	validation_0-error:0.392351	validation_1-error:0.38893
# [8]	validation_0-error:0.392718	validation_1-error:0.387463
# [9]	validation_0-error:0.389418	validation_1-error:0.382331
# [10]	validation_0-error:0.391007	validation_1-error:0.388196
# [11]	validation_0-error:0.388196	validation_1-error:0.388196
# [12]	validation_0-error:0.378055	validation_1-error:0.378299
# [13]	validation_0-error:0.377077	validation_1-error:0.375367
# [14]	validation_0-error:0.375733	validation_1-error:0.375733
# [15]	validation_0-error:0.373534	validation_1-error:0.377566
# [16]	validation_0-error:0.372923	validation_1-error:0.379399
# [17]	validation_0-error:0.37219	validation_1-error:0.380865
# [18]	validation_0-error:0.37109	validation_1-error:0.383065
# [19]	validation_0-error:0.371701	validation_1-error:0.387097
# [20]	validation_0-error:0.370601	validation_1-error:0.384531
# [21]	validation_0-error:0.370357	validation_1-error:0.384164
# [22]	validation_0-error:0.36999	validation_1-error:0.382698
# [23]	validation_0-error:0.370112	validation_1-error:0.381965
# [24]	validation_0-error:0.367302	validation_1-error:0.382331
# [25]	validation_0-error:0.364492	validation_1-error:0.387097
# [26]	validation_0-error:0.361804	validation_1-error:0.385264
# [27]	validation_0-error:0.360215	validation_1-error:0.380865
# [28]	validation_0-error:0.359971	validation_1-error:0.379032
# [29]	validation_0-error:0.359971	validation_1-error:0.379032
# [30]	validation_0-error:0.359726	validation_1-error:0.377933
# [31]	validation_0-error:0.358382	validation_1-error:0.380132
# [32]	validation_0-error:0.357893	validation_1-error:0.382698
# [33]	validation_0-error:0.358993	validation_1-error:0.382331
# Stopping. Best iteration:
# [13]	validation_0-error:0.377077	validation_1-error:0.375367
#
# [0]	validation_0-error:0.428763	validation_1-error:0.409091
# Multiple eval metrics have been passed: 'validation_1-error' will be used for early stopping.
#
# Will train until validation_1-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.423387	validation_1-error:0.421554
# [2]	validation_0-error:0.4174	validation_1-error:0.417522
# [3]	validation_0-error:0.400782	validation_1-error:0.393695
# [4]	validation_0-error:0.40176	validation_1-error:0.393328
# [5]	validation_0-error:0.401515	validation_1-error:0.398827
# [6]	validation_0-error:0.400415	validation_1-error:0.395161
# [7]	validation_0-error:0.40066	validation_1-error:0.396994
# [8]	validation_0-error:0.398827	validation_1-error:0.395528
# [9]	validation_0-error:0.396383	validation_1-error:0.395161
# [10]	validation_0-error:0.395039	validation_1-error:0.395528
# [11]	validation_0-error:0.394917	validation_1-error:0.392229
# [12]	validation_0-error:0.392595	validation_1-error:0.393328
# [13]	validation_0-error:0.387341	validation_1-error:0.396628
# [14]	validation_0-error:0.38563	validation_1-error:0.394428
# [15]	validation_0-error:0.385142	validation_1-error:0.396261
# [16]	validation_0-error:0.385264	validation_1-error:0.384164
# [17]	validation_0-error:0.383798	validation_1-error:0.385997
# [18]	validation_0-error:0.378788	validation_1-error:0.377199
# [19]	validation_0-error:0.375978	validation_1-error:0.374633
# [20]	validation_0-error:0.377688	validation_1-error:0.378666
# [21]	validation_0-error:0.378421	validation_1-error:0.378299
# [22]	validation_0-error:0.378543	validation_1-error:0.378299
# [23]	validation_0-error:0.37891	validation_1-error:0.383065
# [24]	validation_0-error:0.377444	validation_1-error:0.380499
# [25]	validation_0-error:0.376222	validation_1-error:0.376833
# [26]	validation_0-error:0.373778	validation_1-error:0.3761
# [27]	validation_0-error:0.375489	validation_1-error:0.379399
# [28]	validation_0-error:0.3739	validation_1-error:0.380865
# [29]	validation_0-error:0.373167	validation_1-error:0.383798
# [30]	validation_0-error:0.372067	validation_1-error:0.384531
# [31]	validation_0-error:0.372434	validation_1-error:0.381232
# [32]	validation_0-error:0.371701	validation_1-error:0.384897
# [33]	validation_0-error:0.371823	validation_1-error:0.383431
# [34]	validation_0-error:0.370968	validation_1-error:0.381965
# [35]	validation_0-error:0.37219	validation_1-error:0.384164
# [36]	validation_0-error:0.371334	validation_1-error:0.380499
# [37]	validation_0-error:0.369135	validation_1-error:0.379765
# [38]	validation_0-error:0.367791	validation_1-error:0.378666
# [39]	validation_0-error:0.365714	validation_1-error:0.372434
# [40]	validation_0-error:0.36498	validation_1-error:0.371701
# [41]	validation_0-error:0.365469	validation_1-error:0.3739
# [42]	validation_0-error:0.36498	validation_1-error:0.372434
# [43]	validation_0-error:0.36327	validation_1-error:0.371701
# [44]	validation_0-error:0.363759	validation_1-error:0.371701
# [45]	validation_0-error:0.364125	validation_1-error:0.371701
# [46]	validation_0-error:0.362537	validation_1-error:0.372801
# [47]	validation_0-error:0.359971	validation_1-error:0.371334
# [48]	validation_0-error:0.357893	validation_1-error:0.370235
# [49]	validation_0-error:0.358016	validation_1-error:0.370968
# [50]	validation_0-error:0.357649	validation_1-error:0.369868
# [51]	validation_0-error:0.358138	validation_1-error:0.367669
# [52]	validation_0-error:0.356549	validation_1-error:0.368768
# [53]	validation_0-error:0.356427	validation_1-error:0.369868
# [54]	validation_0-error:0.356183	validation_1-error:0.370968
# [55]	validation_0-error:0.356672	validation_1-error:0.371701
# [56]	validation_0-error:0.356916	validation_1-error:0.371701
# [57]	validation_0-error:0.356061	validation_1-error:0.369135
# [58]	validation_0-error:0.355327	validation_1-error:0.372434
# [59]	validation_0-error:0.355327	validation_1-error:0.373167
# [60]	validation_0-error:0.356549	validation_1-error:0.374633
# [61]	validation_0-error:0.356183	validation_1-error:0.373167
# [62]	validation_0-error:0.35716	validation_1-error:0.3739
# [63]	validation_0-error:0.354717	validation_1-error:0.374267
# [64]	validation_0-error:0.355572	validation_1-error:0.374267
# [65]	validation_0-error:0.355205	validation_1-error:0.375
# [66]	validation_0-error:0.355938	validation_1-error:0.370968
# [67]	validation_0-error:0.35716	validation_1-error:0.3739
# [68]	validation_0-error:0.356183	validation_1-error:0.374633
# [69]	validation_0-error:0.355694	validation_1-error:0.373534
# [70]	validation_0-error:0.351173	validation_1-error:0.375367
# [71]	validation_0-error:0.351906	validation_1-error:0.375
# Stopping. Best iteration:
# [51]	validation_0-error:0.358138	validation_1-error:0.367669
#
# [0]	validation_0-error:0.428886	validation_1-error:0.41239
# Multiple eval metrics have been passed: 'validation_1-error' will be used for early stopping.
#
# Will train until validation_1-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.431696	validation_1-error:0.416422
# [2]	validation_0-error:0.413978	validation_1-error:0.408358
# [3]	validation_0-error:0.409702	validation_1-error:0.403592
# [4]	validation_0-error:0.41239	validation_1-error:0.407258
# [5]	validation_0-error:0.411168	validation_1-error:0.406158
# [6]	validation_0-error:0.413856	validation_1-error:0.414223
# [7]	validation_0-error:0.408969	validation_1-error:0.405425
# [8]	validation_0-error:0.406281	validation_1-error:0.40176
# [9]	validation_0-error:0.405059	validation_1-error:0.396628
# [10]	validation_0-error:0.397116	validation_1-error:0.398827
# [11]	validation_0-error:0.393084	validation_1-error:0.393328
# [12]	validation_0-error:0.396872	validation_1-error:0.39956
# [13]	validation_0-error:0.390152	validation_1-error:0.398827
# [14]	validation_0-error:0.380499	validation_1-error:0.385997
# [15]	validation_0-error:0.381109	validation_1-error:0.394062
# [16]	validation_0-error:0.381354	validation_1-error:0.392595
# [17]	validation_0-error:0.380132	validation_1-error:0.38673
# [18]	validation_0-error:0.377199	validation_1-error:0.377566
# [19]	validation_0-error:0.374633	validation_1-error:0.3739
# [20]	validation_0-error:0.373412	validation_1-error:0.374633
# [21]	validation_0-error:0.37109	validation_1-error:0.376833
# [22]	validation_0-error:0.371212	validation_1-error:0.375733
# [23]	validation_0-error:0.369868	validation_1-error:0.382698
# [24]	validation_0-error:0.366202	validation_1-error:0.378299
# [25]	validation_0-error:0.364736	validation_1-error:0.375367
# [26]	validation_0-error:0.365836	validation_1-error:0.3739
# [27]	validation_0-error:0.365469	validation_1-error:0.373167
# [28]	validation_0-error:0.364614	validation_1-error:0.372434
# [29]	validation_0-error:0.36217	validation_1-error:0.374633
# [30]	validation_0-error:0.362781	validation_1-error:0.373534
# [31]	validation_0-error:0.360215	validation_1-error:0.375
# [32]	validation_0-error:0.35826	validation_1-error:0.373167
# [33]	validation_0-error:0.360826	validation_1-error:0.375
# [34]	validation_0-error:0.358016	validation_1-error:0.373534
# [35]	validation_0-error:0.356549	validation_1-error:0.371334
# [36]	validation_0-error:0.355938	validation_1-error:0.370235
# [37]	validation_0-error:0.356183	validation_1-error:0.368402
# [38]	validation_0-error:0.35545	validation_1-error:0.368402
# [39]	validation_0-error:0.354717	validation_1-error:0.367302
# [40]	validation_0-error:0.353861	validation_1-error:0.367669
# [41]	validation_0-error:0.354106	validation_1-error:0.363636
# [42]	validation_0-error:0.354594	validation_1-error:0.364736
# [43]	validation_0-error:0.354839	validation_1-error:0.368402
# [44]	validation_0-error:0.354472	validation_1-error:0.368035
# [45]	validation_0-error:0.354228	validation_1-error:0.368402
# [46]	validation_0-error:0.354472	validation_1-error:0.367669
# [47]	validation_0-error:0.357405	validation_1-error:0.365469
# [48]	validation_0-error:0.357282	validation_1-error:0.369868
# [49]	validation_0-error:0.356672	validation_1-error:0.368402
# [50]	validation_0-error:0.355327	validation_1-error:0.368035
# [51]	validation_0-error:0.351662	validation_1-error:0.366569
# [52]	validation_0-error:0.349585	validation_1-error:0.365469
# [53]	validation_0-error:0.34824	validation_1-error:0.365469
# [54]	validation_0-error:0.348729	validation_1-error:0.366202
# [55]	validation_0-error:0.348485	validation_1-error:0.365836
# [56]	validation_0-error:0.346896	validation_1-error:0.367302
# [57]	validation_0-error:0.351417	validation_1-error:0.372067
# [58]	validation_0-error:0.352395	validation_1-error:0.373534
# [59]	validation_0-error:0.35154	validation_1-error:0.367302
# [60]	validation_0-error:0.352761	validation_1-error:0.366202
# [61]	validation_0-error:0.351906	validation_1-error:0.367669
# Stopping. Best iteration:
# [41]	validation_0-error:0.354106	validation_1-error:0.363636
#
# [0]	validation_0-error:0.430108	validation_1-error:0.430352
# Multiple eval metrics have been passed: 'validation_1-error' will be used for early stopping.
#
# Will train until validation_1-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.424976	validation_1-error:0.42412
# [2]	validation_0-error:0.419966	validation_1-error:0.420821
# [3]	validation_0-error:0.421676	validation_1-error:0.420088
# [4]	validation_0-error:0.422043	validation_1-error:0.420821
# [5]	validation_0-error:0.413612	validation_1-error:0.413123
# [6]	validation_0-error:0.394673	validation_1-error:0.387463
# [7]	validation_0-error:0.392351	validation_1-error:0.38893
# [8]	validation_0-error:0.392718	validation_1-error:0.387463
# [9]	validation_0-error:0.389418	validation_1-error:0.382331
# [10]	validation_0-error:0.391007	validation_1-error:0.388196
# [11]	validation_0-error:0.388196	validation_1-error:0.388196
# [12]	validation_0-error:0.378055	validation_1-error:0.378299
# [13]	validation_0-error:0.377077	validation_1-error:0.375367
# [14]	validation_0-error:0.375733	validation_1-error:0.375733
# [15]	validation_0-error:0.373534	validation_1-error:0.377566
# [16]	validation_0-error:0.372923	validation_1-error:0.379399
# [17]	validation_0-error:0.37219	validation_1-error:0.380865
# [18]	validation_0-error:0.37109	validation_1-error:0.383065
# [19]	validation_0-error:0.371701	validation_1-error:0.387097
# [20]	validation_0-error:0.370601	validation_1-error:0.384531
# [21]	validation_0-error:0.370357	validation_1-error:0.384164
# [22]	validation_0-error:0.36999	validation_1-error:0.382698
# [23]	validation_0-error:0.370112	validation_1-error:0.381965
# [24]	validation_0-error:0.367302	validation_1-error:0.382331
# [25]	validation_0-error:0.364492	validation_1-error:0.387097
# [26]	validation_0-error:0.361804	validation_1-error:0.385264
# [27]	validation_0-error:0.360215	validation_1-error:0.380865
# [28]	validation_0-error:0.359971	validation_1-error:0.379032
# [29]	validation_0-error:0.359971	validation_1-error:0.379032
# [30]	validation_0-error:0.359726	validation_1-error:0.377933
# [31]	validation_0-error:0.358382	validation_1-error:0.380132
# [32]	validation_0-error:0.357893	validation_1-error:0.382698
# [33]	validation_0-error:0.358993	validation_1-error:0.382331
# Stopping. Best iteration:
# [13]	validation_0-error:0.377077	validation_1-error:0.375367
#
# [0]	validation_0-error:0.428763	validation_1-error:0.409091
# Multiple eval metrics have been passed: 'validation_1-error' will be used for early stopping.
#
# Will train until validation_1-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.423387	validation_1-error:0.421554
# [2]	validation_0-error:0.4174	validation_1-error:0.417522
# [3]	validation_0-error:0.400782	validation_1-error:0.393695
# [4]	validation_0-error:0.40176	validation_1-error:0.393328
# [5]	validation_0-error:0.401515	validation_1-error:0.398827
# [6]	validation_0-error:0.400415	validation_1-error:0.395161
# [7]	validation_0-error:0.40066	validation_1-error:0.396994
# [8]	validation_0-error:0.398949	validation_1-error:0.396261
# [9]	validation_0-error:0.396505	validation_1-error:0.395894
# [10]	validation_0-error:0.396383	validation_1-error:0.395894
# [11]	validation_0-error:0.395283	validation_1-error:0.392962
# [12]	validation_0-error:0.394917	validation_1-error:0.393695
# [13]	validation_0-error:0.389907	validation_1-error:0.396261
# [14]	validation_0-error:0.390152	validation_1-error:0.398094
# [15]	validation_0-error:0.388563	validation_1-error:0.400293
# [16]	validation_0-error:0.391373	validation_1-error:0.385997
# [17]	validation_0-error:0.384531	validation_1-error:0.383065
# [18]	validation_0-error:0.383187	validation_1-error:0.383065
# [19]	validation_0-error:0.374267	validation_1-error:0.373534
# [20]	validation_0-error:0.379765	validation_1-error:0.381232
# [21]	validation_0-error:0.381598	validation_1-error:0.379399
# [22]	validation_0-error:0.380865	validation_1-error:0.377199
# [23]	validation_0-error:0.375978	validation_1-error:0.375
# [24]	validation_0-error:0.377566	validation_1-error:0.376466
# [25]	validation_0-error:0.374756	validation_1-error:0.379399
# [26]	validation_0-error:0.374633	validation_1-error:0.377566
# [27]	validation_0-error:0.374267	validation_1-error:0.377199
# [28]	validation_0-error:0.375855	validation_1-error:0.377566
# [29]	validation_0-error:0.374022	validation_1-error:0.375
# [30]	validation_0-error:0.373656	validation_1-error:0.375733
# [31]	validation_0-error:0.370846	validation_1-error:0.377199
# [32]	validation_0-error:0.372923	validation_1-error:0.375
# [33]	validation_0-error:0.373778	validation_1-error:0.374633
# [34]	validation_0-error:0.371945	validation_1-error:0.370235
# [35]	validation_0-error:0.371334	validation_1-error:0.374267
# [36]	validation_0-error:0.371823	validation_1-error:0.377199
# [37]	validation_0-error:0.37219	validation_1-error:0.375
# [38]	validation_0-error:0.369135	validation_1-error:0.371701
# [39]	validation_0-error:0.368157	validation_1-error:0.370601
# [40]	validation_0-error:0.365714	validation_1-error:0.368402
# [41]	validation_0-error:0.364492	validation_1-error:0.369868
# [42]	validation_0-error:0.365225	validation_1-error:0.369501
# [43]	validation_0-error:0.365103	validation_1-error:0.370235
# [44]	validation_0-error:0.365591	validation_1-error:0.375
# [45]	validation_0-error:0.365591	validation_1-error:0.3761
# [46]	validation_0-error:0.364003	validation_1-error:0.375733
# [47]	validation_0-error:0.362903	validation_1-error:0.375
# [48]	validation_0-error:0.363514	validation_1-error:0.375367
# [49]	validation_0-error:0.363148	validation_1-error:0.3739
# [50]	validation_0-error:0.363392	validation_1-error:0.3739
# [51]	validation_0-error:0.365347	validation_1-error:0.372801
# [52]	validation_0-error:0.362048	validation_1-error:0.369135
# [53]	validation_0-error:0.359238	validation_1-error:0.368402
# [54]	validation_0-error:0.358749	validation_1-error:0.368768
# [55]	validation_0-error:0.357893	validation_1-error:0.367669
# [56]	validation_0-error:0.358504	validation_1-error:0.370601
# [57]	validation_0-error:0.359848	validation_1-error:0.369501
# [58]	validation_0-error:0.35826	validation_1-error:0.370601
# [59]	validation_0-error:0.358016	validation_1-error:0.370235
# [60]	validation_0-error:0.35826	validation_1-error:0.369868
# [61]	validation_0-error:0.357893	validation_1-error:0.373534
# [62]	validation_0-error:0.357649	validation_1-error:0.371701
# [63]	validation_0-error:0.357649	validation_1-error:0.370968
# [64]	validation_0-error:0.357282	validation_1-error:0.369135
# [65]	validation_0-error:0.35716	validation_1-error:0.371701
# [66]	validation_0-error:0.35716	validation_1-error:0.371701
# [67]	validation_0-error:0.355083	validation_1-error:0.369501
# [68]	validation_0-error:0.353983	validation_1-error:0.369135
# [69]	validation_0-error:0.353617	validation_1-error:0.370235
# [70]	validation_0-error:0.353495	validation_1-error:0.371334
# [71]	validation_0-error:0.355205	validation_1-error:0.368035
# [72]	validation_0-error:0.354839	validation_1-error:0.369501
# [73]	validation_0-error:0.354472	validation_1-error:0.366569
# [74]	validation_0-error:0.353495	validation_1-error:0.365469
# [75]	validation_0-error:0.353006	validation_1-error:0.368402
# [76]	validation_0-error:0.353861	validation_1-error:0.369135
# [77]	validation_0-error:0.353372	validation_1-error:0.368035
# [78]	validation_0-error:0.35325	validation_1-error:0.367302
# [79]	validation_0-error:0.352761	validation_1-error:0.366935
# [80]	validation_0-error:0.352639	validation_1-error:0.368035
# [81]	validation_0-error:0.352761	validation_1-error:0.366935
# [82]	validation_0-error:0.348851	validation_1-error:0.365469
# [83]	validation_0-error:0.350318	validation_1-error:0.368402
# [84]	validation_0-error:0.349707	validation_1-error:0.367302
# [85]	validation_0-error:0.349218	validation_1-error:0.368402
# [86]	validation_0-error:0.350318	validation_1-error:0.367302
# [87]	validation_0-error:0.349462	validation_1-error:0.368035
# [88]	validation_0-error:0.349707	validation_1-error:0.366569
# [89]	validation_0-error:0.349096	validation_1-error:0.367302
# [90]	validation_0-error:0.34934	validation_1-error:0.366569
# [91]	validation_0-error:0.350929	validation_1-error:0.365836
# [92]	validation_0-error:0.350318	validation_1-error:0.370968
# [93]	validation_0-error:0.350318	validation_1-error:0.371701
# [94]	validation_0-error:0.349096	validation_1-error:0.369501
# Stopping. Best iteration:
# [74]	validation_0-error:0.353495	validation_1-error:0.365469
#
# [0]	validation_0-error:0.428886	validation_1-error:0.41239
# Multiple eval metrics have been passed: 'validation_1-error' will be used for early stopping.
#
# Will train until validation_1-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.431696	validation_1-error:0.416422
# [2]	validation_0-error:0.413978	validation_1-error:0.408358
# [3]	validation_0-error:0.409702	validation_1-error:0.403592
# [4]	validation_0-error:0.41239	validation_1-error:0.407258
# [5]	validation_0-error:0.411779	validation_1-error:0.406525
# [6]	validation_0-error:0.411413	validation_1-error:0.405059
# [7]	validation_0-error:0.408969	validation_1-error:0.405792
# [8]	validation_0-error:0.406281	validation_1-error:0.403226
# [9]	validation_0-error:0.405059	validation_1-error:0.396994
# [10]	validation_0-error:0.396872	validation_1-error:0.399194
# [11]	validation_0-error:0.392229	validation_1-error:0.393695
# [12]	validation_0-error:0.396628	validation_1-error:0.398827
# [13]	validation_0-error:0.392229	validation_1-error:0.399927
# [14]	validation_0-error:0.389663	validation_1-error:0.390029
# [15]	validation_0-error:0.386241	validation_1-error:0.390762
# [16]	validation_0-error:0.384042	validation_1-error:0.385264
# [17]	validation_0-error:0.383431	validation_1-error:0.384164
# [18]	validation_0-error:0.377199	validation_1-error:0.3739
# [19]	validation_0-error:0.377566	validation_1-error:0.374267
# [20]	validation_0-error:0.378177	validation_1-error:0.382698
# [21]	validation_0-error:0.377077	validation_1-error:0.380499
# [22]	validation_0-error:0.375122	validation_1-error:0.378299
# [23]	validation_0-error:0.373045	validation_1-error:0.374633
# [24]	validation_0-error:0.374756	validation_1-error:0.373167
# [25]	validation_0-error:0.371212	validation_1-error:0.372434
# [26]	validation_0-error:0.372067	validation_1-error:0.372067
# [27]	validation_0-error:0.371457	validation_1-error:0.371701
# [28]	validation_0-error:0.369746	validation_1-error:0.373167
# [29]	validation_0-error:0.366325	validation_1-error:0.374633
# [30]	validation_0-error:0.366447	validation_1-error:0.374267
# [31]	validation_0-error:0.368157	validation_1-error:0.376833
# [32]	validation_0-error:0.364614	validation_1-error:0.372067
# [33]	validation_0-error:0.362048	validation_1-error:0.367302
# [34]	validation_0-error:0.365103	validation_1-error:0.377566
# [35]	validation_0-error:0.365103	validation_1-error:0.374267
# [36]	validation_0-error:0.36437	validation_1-error:0.374633
# [37]	validation_0-error:0.363514	validation_1-error:0.373167
# [38]	validation_0-error:0.365836	validation_1-error:0.373534
# [39]	validation_0-error:0.363759	validation_1-error:0.369135
# [40]	validation_0-error:0.36217	validation_1-error:0.368768
# [41]	validation_0-error:0.362659	validation_1-error:0.368035
# [42]	validation_0-error:0.361804	validation_1-error:0.372067
# [43]	validation_0-error:0.360948	validation_1-error:0.371334
# [44]	validation_0-error:0.360459	validation_1-error:0.369868
# [45]	validation_0-error:0.360337	validation_1-error:0.370968
# [46]	validation_0-error:0.360093	validation_1-error:0.370601
# [47]	validation_0-error:0.360459	validation_1-error:0.368035
# [48]	validation_0-error:0.360948	validation_1-error:0.368402
# [49]	validation_0-error:0.361804	validation_1-error:0.368768
# [50]	validation_0-error:0.359604	validation_1-error:0.371334
# [51]	validation_0-error:0.357893	validation_1-error:0.369135
# [52]	validation_0-error:0.358504	validation_1-error:0.365469
# [53]	validation_0-error:0.356672	validation_1-error:0.367669
# [54]	validation_0-error:0.357527	validation_1-error:0.365103
# [55]	validation_0-error:0.356672	validation_1-error:0.365836
# [56]	validation_0-error:0.358504	validation_1-error:0.366202
# [57]	validation_0-error:0.357527	validation_1-error:0.366569
# [58]	validation_0-error:0.357282	validation_1-error:0.364003
# [59]	validation_0-error:0.35826	validation_1-error:0.364736
# [60]	validation_0-error:0.358871	validation_1-error:0.366569
# [61]	validation_0-error:0.356916	validation_1-error:0.365469
# [62]	validation_0-error:0.356305	validation_1-error:0.36437
# [63]	validation_0-error:0.357038	validation_1-error:0.364736
# [64]	validation_0-error:0.35545	validation_1-error:0.36217
# [65]	validation_0-error:0.354961	validation_1-error:0.361804
# [66]	validation_0-error:0.355205	validation_1-error:0.361804
# [67]	validation_0-error:0.354472	validation_1-error:0.362537
# [68]	validation_0-error:0.354472	validation_1-error:0.36217
# [69]	validation_0-error:0.353739	validation_1-error:0.36217
# [70]	validation_0-error:0.351417	validation_1-error:0.36217
# [71]	validation_0-error:0.35154	validation_1-error:0.355938
# [72]	validation_0-error:0.350806	validation_1-error:0.358871
# [73]	validation_0-error:0.349462	validation_1-error:0.361437
# [74]	validation_0-error:0.347874	validation_1-error:0.361437
# [75]	validation_0-error:0.347752	validation_1-error:0.361804
# [76]	validation_0-error:0.348729	validation_1-error:0.362903
# [77]	validation_0-error:0.348729	validation_1-error:0.36217
# [78]	validation_0-error:0.34934	validation_1-error:0.360704
# [79]	validation_0-error:0.348363	validation_1-error:0.362537
# [80]	validation_0-error:0.347263	validation_1-error:0.36107
# [81]	validation_0-error:0.346896	validation_1-error:0.361437
# [82]	validation_0-error:0.347141	validation_1-error:0.36217
# [83]	validation_0-error:0.345674	validation_1-error:0.36217
# [84]	validation_0-error:0.346041	validation_1-error:0.362903
# [85]	validation_0-error:0.345552	validation_1-error:0.36217
# [86]	validation_0-error:0.34433	validation_1-error:0.361437
# [87]	validation_0-error:0.343475	validation_1-error:0.361804
# [88]	validation_0-error:0.344819	validation_1-error:0.359238
# [89]	validation_0-error:0.342375	validation_1-error:0.363636
# [90]	validation_0-error:0.341887	validation_1-error:0.36327
# [91]	validation_0-error:0.34152	validation_1-error:0.36217
# Stopping. Best iteration:
# [71]	validation_0-error:0.35154	validation_1-error:0.355938
#
# [0]	validation_0-error:0.430108	validation_1-error:0.430352
# Multiple eval metrics have been passed: 'validation_1-error' will be used for early stopping.
# Will train until validation_1-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.424976	validation_1-error:0.42412
# [2]	validation_0-error:0.419966	validation_1-error:0.420821
# [3]	validation_0-error:0.421554	validation_1-error:0.420455
# [4]	validation_0-error:0.422043	validation_1-error:0.421188
# [5]	validation_0-error:0.394306	validation_1-error:0.404326
# [6]	validation_0-error:0.388685	validation_1-error:0.396994
# [7]	validation_0-error:0.387219	validation_1-error:0.396261
# [8]	validation_0-error:0.386241	validation_1-error:0.396994
# [9]	validation_0-error:0.402493	validation_1-error:0.408724
# [10]	validation_0-error:0.400538	validation_1-error:0.406158
# [11]	validation_0-error:0.393695	validation_1-error:0.397727
# [12]	validation_0-error:0.391007	validation_1-error:0.396628
# [13]	validation_0-error:0.39174	validation_1-error:0.391862
# [14]	validation_0-error:0.384897	validation_1-error:0.387463
# [15]	validation_0-error:0.380376	validation_1-error:0.392229
# [16]	validation_0-error:0.380254	validation_1-error:0.388563
# [17]	validation_0-error:0.378177	validation_1-error:0.387463
# [18]	validation_0-error:0.377444	validation_1-error:0.38563
# [19]	validation_0-error:0.3761	validation_1-error:0.385997
# [20]	validation_0-error:0.374145	validation_1-error:0.380499
# [21]	validation_0-error:0.374145	validation_1-error:0.384897
# [22]	validation_0-error:0.374267	validation_1-error:0.382331
# [23]	validation_0-error:0.370723	validation_1-error:0.385997
# [24]	validation_0-error:0.369501	validation_1-error:0.384531
# [25]	validation_0-error:0.367058	validation_1-error:0.385264
# [26]	validation_0-error:0.36718	validation_1-error:0.382331
# [27]	validation_0-error:0.367302	validation_1-error:0.381232
# [28]	validation_0-error:0.367424	validation_1-error:0.382331
# [29]	validation_0-error:0.366813	validation_1-error:0.382698
# [30]	validation_0-error:0.363636	validation_1-error:0.384531
# [31]	validation_0-error:0.365225	validation_1-error:0.383798
# [32]	validation_0-error:0.364125	validation_1-error:0.380865
# [33]	validation_0-error:0.36437	validation_1-error:0.380865
# [34]	validation_0-error:0.363392	validation_1-error:0.382698
# [35]	validation_0-error:0.360948	validation_1-error:0.379032
# [36]	validation_0-error:0.359848	validation_1-error:0.378299
# [37]	validation_0-error:0.35826	validation_1-error:0.380865
# [38]	validation_0-error:0.35826	validation_1-error:0.380865
# [39]	validation_0-error:0.358627	validation_1-error:0.381965
# [40]	validation_0-error:0.359115	validation_1-error:0.38673
# [41]	validation_0-error:0.358749	validation_1-error:0.383431
# [42]	validation_0-error:0.357405	validation_1-error:0.380499
# [43]	validation_0-error:0.356183	validation_1-error:0.381965
# [44]	validation_0-error:0.358138	validation_1-error:0.382698
# [45]	validation_0-error:0.358016	validation_1-error:0.381965
# [46]	validation_0-error:0.354228	validation_1-error:0.379399
# [47]	validation_0-error:0.351662	validation_1-error:0.373534
# [48]	validation_0-error:0.350929	validation_1-error:0.370968
# ...
# [114]	validation_0-error:0.321237	validation_1-error:0.357405
# [115]	validation_0-error:0.318915	validation_1-error:0.355938
# [116]	validation_0-error:0.317815	validation_1-error:0.354839
# [117]	validation_0-error:0.317082	validation_1-error:0.356305
# [118]	validation_0-error:0.316838	validation_1-error:0.354839
# [119]	validation_0-error:0.316471	validation_1-error:0.354106
# [120]	validation_0-error:0.316716	validation_1-error:0.354472
# [121]	validation_0-error:0.316838	validation_1-error:0.354839
# [122]	validation_0-error:0.315127	validation_1-error:0.354472
# [123]	validation_0-error:0.31415	validation_1-error:0.354106
# [124]	validation_0-error:0.31415	validation_1-error:0.353739
# [125]	validation_0-error:0.313172	validation_1-error:0.353739
# [126]	validation_0-error:0.314272	validation_1-error:0.354472
# [127]	validation_0-error:0.313416	validation_1-error:0.353006
# [128]	validation_0-error:0.313172	validation_1-error:0.354106
# [129]	validation_0-error:0.312928	validation_1-error:0.353739
# [130]	validation_0-error:0.312928	validation_1-error:0.355205
# [131]	validation_0-error:0.311217	validation_1-error:0.354106
# [132]	validation_0-error:0.311706	validation_1-error:0.354839
# [133]	validation_0-error:0.311706	validation_1-error:0.353739
# [134]	validation_0-error:0.312195	validation_1-error:0.354106
# [135]	validation_0-error:0.312928	validation_1-error:0.352639
# [136]	validation_0-error:0.312805	validation_1-error:0.352639
# [137]	validation_0-error:0.312072	validation_1-error:0.353006
# [138]	validation_0-error:0.312317	validation_1-error:0.35154
# [139]	validation_0-error:0.312195	validation_1-error:0.353006
# [140]	validation_0-error:0.31195	validation_1-error:0.353006
# [141]	validation_0-error:0.311339	validation_1-error:0.353006
# [142]	validation_0-error:0.311706	validation_1-error:0.352639
# [143]	validation_0-error:0.310973	validation_1-error:0.35154
# [144]	validation_0-error:0.310973	validation_1-error:0.35154
# [145]	validation_0-error:0.311339	validation_1-error:0.351906
# [146]	validation_0-error:0.310117	validation_1-error:0.353739
# [147]	validation_0-error:0.309384	validation_1-error:0.353006
# [148]	validation_0-error:0.308651	validation_1-error:0.352273
# [149]	validation_0-error:0.308529	validation_1-error:0.353006
# [150]	validation_0-error:0.307796	validation_1-error:0.350806
# [151]	validation_0-error:0.307307	validation_1-error:0.349707
# [152]	validation_0-error:0.30694	validation_1-error:0.351173
# [153]	validation_0-error:0.306696	validation_1-error:0.35154
# [154]	validation_0-error:0.306574	validation_1-error:0.352639
# [155]	validation_0-error:0.30523	validation_1-error:0.352639
# [156]	validation_0-error:0.305474	validation_1-error:0.353006
# [157]	validation_0-error:0.304985	validation_1-error:0.353006
# [158]	validation_0-error:0.304741	validation_1-error:0.351906
# [159]	validation_0-error:0.304008	validation_1-error:0.34934
# [160]	validation_0-error:0.303641	validation_1-error:0.34934
# [161]	validation_0-error:0.303886	validation_1-error:0.34934
# [162]	validation_0-error:0.302664	validation_1-error:0.34934
# [163]	validation_0-error:0.302175	validation_1-error:0.348607
# [164]	validation_0-error:0.301564	validation_1-error:0.348607
# [165]	validation_0-error:0.301564	validation_1-error:0.348607
# [166]	validation_0-error:0.300709	validation_1-error:0.346774
# [167]	validation_0-error:0.300831	validation_1-error:0.346774
# [168]	validation_0-error:0.299853	validation_1-error:0.347141
# [169]	validation_0-error:0.298387	validation_1-error:0.346774
# [170]	validation_0-error:0.298876	validation_1-error:0.347141
# [171]	validation_0-error:0.29912	validation_1-error:0.34824
# [172]	validation_0-error:0.297532	validation_1-error:0.350073
# [173]	validation_0-error:0.297287	validation_1-error:0.349707
# [174]	validation_0-error:0.296554	validation_1-error:0.34824
# [175]	validation_0-error:0.29741	validation_1-error:0.347507
# [176]	validation_0-error:0.29741	validation_1-error:0.347507
# [177]	validation_0-error:0.296921	validation_1-error:0.347507
# [178]	validation_0-error:0.29631	validation_1-error:0.34824
# [179]	validation_0-error:0.296676	validation_1-error:0.34934
# [180]	validation_0-error:0.296188	validation_1-error:0.349707
# [181]	validation_0-error:0.295088	validation_1-error:0.348974
# [182]	validation_0-error:0.295332	validation_1-error:0.349707
# [183]	validation_0-error:0.295088	validation_1-error:0.34934
# [184]	validation_0-error:0.29411	validation_1-error:0.350073
# [185]	validation_0-error:0.294844	validation_1-error:0.35044
# [186]	validation_0-error:0.294477	validation_1-error:0.350073
# Stopping. Best iteration:
# [166]	validation_0-error:0.300709	validation_1-error:0.346774
#
# [0]	validation_0-error:0.395528	validation_1-error:0.390762
# Multiple eval metrics have been passed: 'validation_1-error' will be used for early stopping.
#
# Will train until validation_1-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.392962	validation_1-error:0.388196
# [2]	validation_0-error:0.381476	validation_1-error:0.380865
# [3]	validation_0-error:0.382087	validation_1-error:0.381232
# [4]	validation_0-error:0.377566	validation_1-error:0.381965
# [5]	validation_0-error:0.37891	validation_1-error:0.379032
# [6]	validation_0-error:0.369868	validation_1-error:0.378666
# [7]	validation_0-error:0.366325	validation_1-error:0.375
# [8]	validation_0-error:0.365958	validation_1-error:0.380865
# [9]	validation_0-error:0.36608	validation_1-error:0.380865
# [10]	validation_0-error:0.365714	validation_1-error:0.382331
# [11]	validation_0-error:0.365103	validation_1-error:0.384897
# [12]	validation_0-error:0.36327	validation_1-error:0.377933
# [13]	validation_0-error:0.36107	validation_1-error:0.379765
# [14]	validation_0-error:0.358016	validation_1-error:0.377566
# [15]	validation_0-error:0.359604	validation_1-error:0.378299
# [16]	validation_0-error:0.354228	validation_1-error:0.377566
# [17]	validation_0-error:0.355572	validation_1-error:0.376833
# [18]	validation_0-error:0.357527	validation_1-error:0.376466
# [19]	validation_0-error:0.355572	validation_1-error:0.379032
# [20]	validation_0-error:0.355205	validation_1-error:0.379032
# [21]	validation_0-error:0.354961	validation_1-error:0.375
# [22]	validation_0-error:0.356061	validation_1-error:0.374633
# [23]	validation_0-error:0.356916	validation_1-error:0.373534
# [24]	validation_0-error:0.356672	validation_1-error:0.372434
# [25]	validation_0-error:0.353617	validation_1-error:0.373534
# [26]	validation_0-error:0.353006	validation_1-error:0.372434
# [27]	validation_0-error:0.356183	validation_1-error:0.373167
# [28]	validation_0-error:0.356427	validation_1-error:0.369501
# [29]	validation_0-error:0.356916	validation_1-error:0.369868
# [30]	validation_0-error:0.350929	validation_1-error:0.368035
# [31]	validation_0-error:0.353861	validation_1-error:0.372801
# [32]	validation_0-error:0.351417	validation_1-error:0.366202
# [33]	validation_0-error:0.350806	validation_1-error:0.366202
# [34]	validation_0-error:0.351295	validation_1-error:0.366569
# [35]	validation_0-error:0.349951	validation_1-error:0.365469
# [36]	validation_0-error:0.349707	validation_1-error:0.365836
# [37]	validation_0-error:0.350562	validation_1-error:0.365103
# [38]	validation_0-error:0.349218	validation_1-error:0.367302
# [39]	validation_0-error:0.347019	validation_1-error:0.365836
# [40]	validation_0-error:0.345797	validation_1-error:0.365469
# [41]	validation_0-error:0.345919	validation_1-error:0.364003
# [42]	validation_0-error:0.34653	validation_1-error:0.36437
# [43]	validation_0-error:0.344819	validation_1-error:0.363636
# [44]	validation_0-error:0.342375	validation_1-error:0.36437
# [45]	validation_0-error:0.342375	validation_1-error:0.365103
# [46]	validation_0-error:0.34262	validation_1-error:0.363636
# [47]	validation_0-error:0.342742	validation_1-error:0.365103
# [48]	validation_0-error:0.342498	validation_1-error:0.365103
# [49]	validation_0-error:0.342131	validation_1-error:0.365469
# [50]	validation_0-error:0.342498	validation_1-error:0.365469
# [51]	validation_0-error:0.341887	validation_1-error:0.366202
# [52]	validation_0-error:0.339321	validation_1-error:0.362537
# [53]	validation_0-error:0.336388	validation_1-error:0.36327
# [54]	validation_0-error:0.336022	validation_1-error:0.36327
# [55]	validation_0-error:0.336999	validation_1-error:0.365469
# [56]	validation_0-error:0.336877	validation_1-error:0.366569
# [57]	validation_0-error:0.336144	validation_1-error:0.365836
# [58]	validation_0-error:0.331989	validation_1-error:0.36217
# [59]	validation_0-error:0.330279	validation_1-error:0.360337
# [60]	validation_0-error:0.330034	validation_1-error:0.359604
# [61]	validation_0-error:0.330034	validation_1-error:0.359238
# [62]	validation_0-error:0.330523	validation_1-error:0.358871
# [63]	validation_0-error:0.32979	validation_1-error:0.359238
# [64]	validation_0-error:0.329912	validation_1-error:0.357405
# [65]	validation_0-error:0.330767	validation_1-error:0.359604
# [66]	validation_0-error:0.328935	validation_1-error:0.359604
# [67]	validation_0-error:0.329179	validation_1-error:0.359604
# [68]	validation_0-error:0.326491	validation_1-error:0.36107
# [69]	validation_0-error:0.327102	validation_1-error:0.361437
# [70]	validation_0-error:0.326857	validation_1-error:0.359971
# [71]	validation_0-error:0.32759	validation_1-error:0.359238
# [72]	validation_0-error:0.325758	validation_1-error:0.357405
# [73]	validation_0-error:0.324658	validation_1-error:0.357771
# [74]	validation_0-error:0.32368	validation_1-error:0.356672
# [75]	validation_0-error:0.323803	validation_1-error:0.356672
# [76]	validation_0-error:0.323803	validation_1-error:0.356305
# [77]	validation_0-error:0.323192	validation_1-error:0.354106
# [78]	validation_0-error:0.325758	validation_1-error:0.357038
# [79]	validation_0-error:0.325391	validation_1-error:0.358871
# [80]	validation_0-error:0.323803	validation_1-error:0.357771
# [81]	validation_0-error:0.321481	validation_1-error:0.357771
# [82]	validation_0-error:0.322703	validation_1-error:0.357405
# [83]	validation_0-error:0.32197	validation_1-error:0.357038
# [84]	validation_0-error:0.32197	validation_1-error:0.357771
# [85]	validation_0-error:0.32087	validation_1-error:0.357038
# [86]	validation_0-error:0.321725	validation_1-error:0.357038
# [87]	validation_0-error:0.321481	validation_1-error:0.357038
# [88]	validation_0-error:0.321359	validation_1-error:0.357405
# [89]	validation_0-error:0.320992	validation_1-error:0.355572
# [90]	validation_0-error:0.320137	validation_1-error:0.355572
# [91]	validation_0-error:0.318671	validation_1-error:0.352639
# [92]	validation_0-error:0.319037	validation_1-error:0.353739
# [93]	validation_0-error:0.319648	validation_1-error:0.353372
# [94]	validation_0-error:0.317937	validation_1-error:0.354472
# [95]	validation_0-error:0.317571	validation_1-error:0.353006
# [96]	validation_0-error:0.318182	validation_1-error:0.352639
# [97]	validation_0-error:0.318548	validation_1-error:0.353372
# [98]	validation_0-error:0.317571	validation_1-error:0.353739
# [99]	validation_0-error:0.317449	validation_1-error:0.354472
# [100]	validation_0-error:0.317571	validation_1-error:0.355205
# [101]	validation_0-error:0.315982	validation_1-error:0.354839
# [102]	validation_0-error:0.31586	validation_1-error:0.354472
# [103]	validation_0-error:0.314883	validation_1-error:0.353739
# [104]	validation_0-error:0.315616	validation_1-error:0.354839
# [105]	validation_0-error:0.315005	validation_1-error:0.354472
# [106]	validation_0-error:0.315249	validation_1-error:0.354472
# [107]	validation_0-error:0.314761	validation_1-error:0.354472
# [108]	validation_0-error:0.315127	validation_1-error:0.353739
# [109]	validation_0-error:0.313661	validation_1-error:0.353739
# [110]	validation_0-error:0.313783	validation_1-error:0.354472
# [111]	validation_0-error:0.314272	validation_1-error:0.354839
# Stopping. Best iteration:
# [91]	validation_0-error:0.318671	validation_1-error:0.352639
#
# [0]	validation_0-error:0.408358	validation_1-error:0.417155
# Multiple eval metrics have been passed: 'validation_1-error' will be used for early stopping.
#
# Will train until validation_1-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.386608	validation_1-error:0.392595
# [2]	validation_0-error:0.378666	validation_1-error:0.386364
# [3]	validation_0-error:0.363148	validation_1-error:0.372067
# [4]	validation_0-error:0.360459	validation_1-error:0.369501
# [5]	validation_0-error:0.351784	validation_1-error:0.367669
# [6]	validation_0-error:0.353495	validation_1-error:0.365469
# [7]	validation_0-error:0.348607	validation_1-error:0.357405
# [8]	validation_0-error:0.346041	validation_1-error:0.360704
# [9]	validation_0-error:0.34433	validation_1-error:0.358504
# [10]	validation_0-error:0.338343	validation_1-error:0.361437
# [11]	validation_0-error:0.335655	validation_1-error:0.360337
# [12]	validation_0-error:0.333089	validation_1-error:0.361804
# [13]	validation_0-error:0.331012	validation_1-error:0.359238
# [14]	validation_0-error:0.326246	validation_1-error:0.355572
# [15]	validation_0-error:0.322581	validation_1-error:0.35044
# [16]	validation_0-error:0.317815	validation_1-error:0.346041
# [17]	validation_0-error:0.31415	validation_1-error:0.347874
# [18]	validation_0-error:0.31085	validation_1-error:0.344941
# [19]	validation_0-error:0.309506	validation_1-error:0.351906
# [20]	validation_0-error:0.305718	validation_1-error:0.350806
# [21]	validation_0-error:0.303275	validation_1-error:0.352639
# [22]	validation_0-error:0.300953	validation_1-error:0.352273
# [23]	validation_0-error:0.298387	validation_1-error:0.350073
# [24]	validation_0-error:0.299365	validation_1-error:0.348974
# [25]	validation_0-error:0.296799	validation_1-error:0.347507
# [26]	validation_0-error:0.293744	validation_1-error:0.35044
# [27]	validation_0-error:0.293255	validation_1-error:0.351906
# [28]	validation_0-error:0.287757	validation_1-error:0.346041
# [29]	validation_0-error:0.286779	validation_1-error:0.344575
# [30]	validation_0-error:0.281891	validation_1-error:0.344941
# [31]	validation_0-error:0.280425	validation_1-error:0.346408
# [32]	validation_0-error:0.280792	validation_1-error:0.347141
# [33]	validation_0-error:0.279936	validation_1-error:0.346408
# [34]	validation_0-error:0.279081	validation_1-error:0.343109
# [35]	validation_0-error:0.277859	validation_1-error:0.344941
# [36]	validation_0-error:0.275904	validation_1-error:0.340909
# [37]	validation_0-error:0.27456	validation_1-error:0.340909
# [38]	validation_0-error:0.273705	validation_1-error:0.343475
# [39]	validation_0-error:0.272972	validation_1-error:0.339443
# [40]	validation_0-error:0.270283	validation_1-error:0.335777
# [41]	validation_0-error:0.269306	validation_1-error:0.335411
# [42]	validation_0-error:0.268817	validation_1-error:0.335777
# [43]	validation_0-error:0.268817	validation_1-error:0.333944
# [44]	validation_0-error:0.266618	validation_1-error:0.333944
# [45]	validation_0-error:0.263563	validation_1-error:0.338343
# [46]	validation_0-error:0.262952	validation_1-error:0.33761
# [47]	validation_0-error:0.261119	validation_1-error:0.340909
# [48]	validation_0-error:0.260753	validation_1-error:0.342009
# [49]	validation_0-error:0.259897	validation_1-error:0.337243
# [50]	validation_0-error:0.258187	validation_1-error:0.343109
# [51]	validation_0-error:0.259286	validation_1-error:0.342375
# [52]	validation_0-error:0.258065	validation_1-error:0.342375
# [53]	validation_0-error:0.257698	validation_1-error:0.342009
# [54]	validation_0-error:0.254643	validation_1-error:0.340176
# [55]	validation_0-error:0.253543	validation_1-error:0.340176
# [56]	validation_0-error:0.253177	validation_1-error:0.340543
# [57]	validation_0-error:0.251466	validation_1-error:0.338343
# [58]	validation_0-error:0.250978	validation_1-error:0.338343
# [59]	validation_0-error:0.250733	validation_1-error:0.340543
# [60]	validation_0-error:0.249145	validation_1-error:0.342009
# [61]	validation_0-error:0.250733	validation_1-error:0.342375
# [62]	validation_0-error:0.249145	validation_1-error:0.341642
# [63]	validation_0-error:0.247312	validation_1-error:0.340176
# Stopping. Best iteration:
# [43]	validation_0-error:0.268817	validation_1-error:0.333944
#
# Grid Search found the following optimal parameters:
# learning_rate: 0.7
# max_depth: 4
# min_child_weight: 5
# n_estimators: 300
#
# Training Accuracy: 73.12%
# Validation accuracy: 66.61%

# %% [markdown]
# ### Import all needed libraries and set our seed

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import SMOTE
np.random.seed(0)
import xgboost as xgb

# %% [markdown]
# ### read in our cleaned up dataset

# %%
df = pd.read_csv('../mod_three_project/new_2018_citibike_data.cvs')

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
start_nhbr = pd.read_csv('start_neighborhoods')

# %%
start_nhbr.drop(['Unnamed: 0','start station name'],inplace=True,axis=1)

# %%
df_w_snhbr = result = pd.merge(df, start_nhbr, on=['start station id'])

# %%
df_w_snhbr = df_w_snhbr[['start_nhbr', 'usertype', 'gender', 'start_month',
                         'start_day_of_week', 'start_hour', 'ave_temp', 'precip', 
                         'snow_depth','birth_yr_range', 'start_hr_range','stop_nhbr']]

# %%
df_w_snhbr.head()
# Out:
#    start_nhbr  usertype  gender  start_month  start_day_of_week  start_hour  \
# 0  Tudor City         1       1            1                  1           7
# 1  Tudor City         1       1            1                  1           7
# 2  Tudor City         1       1            1                  1           7
# 3  Tudor City         1       1            1                  5          18
# 4  Tudor City         1       1            1                  5          18
#
#    ave_temp  precip  snow_depth birth_yr_range start_hr_range     stop_nhbr
# 0      19.5     0.0           0    1964 - 1971         0 - 11       Tribeca
# 1      19.5     0.0           0    1964 - 1971         0 - 11       Tribeca
# 2      19.5     0.0           0    1964 - 1971         0 - 11       Tribeca
# 3      45.0     0.0           0    1988 - 1995        12 - 23  Williamsburg
# 4      45.0     0.0           0    1988 - 1995        12 - 23  Williamsburg

# %% [markdown]
# Lets get a sample from our dataset

# %%
df_small = df.sample(5000,random_state=42)

# %%
df_small.columns
# Out:
# Index(['start station id', 'usertype', 'gender', 'start_month',
#        'start_day_of_week', 'start_hour', 'ave_temp', 'precip', 'snow_depth',
#        'stop_nhbr', 'birth_yr_range', 'start_hr_range'],
#       dtype='object')

# %%
#let see how many neighborhoods we have
len(list(df_small.stop_nhbr.value_counts()))
# Out:
# 51

# %% [markdown]
# get sample from df with start neighborhoods

# %%
df_w_snhbr_sm = df_w_snhbr.sample(5000,random_state=42)

# %% [markdown]
# ### separate the target and the predictors

# %%
target = df_small.stop_nhbr

# %%
df_small.dtypes
# Out:
# start station id     float64
# usertype               int64
# gender                 int64
# start_month            int64
# start_day_of_week      int64
# start_hour             int64
# ave_temp             float64
# precip               float64
# snow_depth             int64
# stop_nhbr             object
# birth_yr_range        object
# start_hr_range        object
# dtype: object

# %% [markdown]
# __Separate target and predictors from df with start neighborhoods__

# %%
df_w_snhbr_sm.to_csv('citibike_data_with_strt_nhbr.csv')

# %%
target_snhbr = df_w_snhbr_sm.stop_nhbr

# %%
data_snhbr = pd.get_dummies(df_w_snhbr_sm[df_w_snhbr_sm.columns[:-1]])

# %%
data_snhbr.head(3)
# Out:
#          usertype  gender  start_month  start_day_of_week  start_hour  \
# 180088          1       1            6                  4          15
# 2441387         1       1            7                  1           8
# 433909          1       1            3                  0           9
#
#          ave_temp  precip  snow_depth  start_nhbr_Astoria  \
# 180088       68.5    0.10           0                   0
# 2441387      79.0    2.24           0                   0
# 433909       38.0    0.00           0                   0
#
#          start_nhbr_Battery Park           ...            \
# 180088                         0           ...
# 2441387                        0           ...
# 433909                         0           ...
#
#          birth_yr_range_1940 - 1947  birth_yr_range_1948 - 1955  \
# 180088                            0                           0
# 2441387                           0                           1
# 433909                            0                           0
#
#          birth_yr_range_1956 - 1963  birth_yr_range_1964 - 1971  \
# 180088                            0                           0
# 2441387                           0                           0
# 433909                            0                           0
#
#          birth_yr_range_1972 - 1979  birth_yr_range_1980 - 1987  \
# 180088                            0                           1
# 2441387                           0                           0
# 433909                            0                           0
#
#          birth_yr_range_1988 - 1995  birth_yr_range_1996 - 2003  \
# 180088                            0                           0
# 2441387                           0                           0
# 433909                            1                           0
#
#          start_hr_range_0 - 11  start_hr_range_12 - 23
# 180088                       0                       1
# 2441387                      1                       0
# 433909                       1                       0
#
# [3 rows x 66 columns]

# %% [markdown]
# ### Create dummies from our catrgorical data in our predictors ( birth_yr_range, start_hr_range)

# %%
data = pd.get_dummies(df_small[['start station id','usertype', 'gender',
                            'start_month', 'start_day_of_week',
                            'start_hour', 'ave_temp','precip', 
                            'snow_depth', 'birth_yr_range',
                            'start_hr_range']])

# %%
data.head()
# Out:
#         start station id  usertype  gender  start_month  start_day_of_week  \
# 543507             526.0         1       0            5                  1
# 361736             144.0         1       1            4                  5
# 447442            3167.0         0       0            5                  6
# 472328             499.0         1       1            5                  3
# 351878             448.0         1       1            4                  3
#
#         start_hour  ave_temp  precip  snow_depth  birth_yr_range_1940 - 1947  \
# 543507          14      76.0    0.00           0                           0
# 361736          16      60.5    0.00           0                           0
# 447442           9      61.0    0.00           0                           0
# 472328          18      63.5    0.22           0                           0
# 351878          22      54.5    0.00           0                           0
#
#         birth_yr_range_1948 - 1955  birth_yr_range_1956 - 1963  \
# 543507                           0                           0
# 361736                           0                           0
# 447442                           0                           0
# 472328                           0                           0
# 351878                           0                           0
#
#         birth_yr_range_1964 - 1971  birth_yr_range_1972 - 1979  \
# 543507                           0                           0
# 361736                           0                           0
# 447442                           0                           0
# 472328                           1                           0
# 351878                           0                           0
#
#         birth_yr_range_1980 - 1987  birth_yr_range_1988 - 1995  \
# 543507                           1                           0
# 361736                           1                           0
# 447442                           1                           0
# 472328                           0                           0
# 351878                           1                           0
#
#         birth_yr_range_1996 - 2003  start_hr_range_0 - 11  \
# 543507                           0                      0
# 361736                           0                      0
# 447442                           0                      1
# 472328                           0                      0
# 351878                           0                      0
#
#         start_hr_range_12 - 23
# 543507                       1
# 361736                       1
# 447442                       0
# 472328                       1
# 351878                       1

# %%
target.shape,data.shape
# Out:
# ((5000,), (5000, 19))

# %% [markdown]
# ### Do train test split for the data
#
# we have chose the 80/20 split as our ratio

# %%
data_train, data_test, target_train, target_test = train_test_split(data,target,test_size=0.2)

# %% [markdown]
# __train test split for DataFramew with start neighborhood__

# %%
data_train_sn, data_test_sn, target_train_sn, target_test_sn = train_test_split(data_snhbr,target_snhbr,test_size=0.2)

# %% [markdown]
# ### Baseline Models

# %%
BL_tree_clf = DecisionTreeClassifier(criterion = "gini", max_depth = 5) 
BL_tree_clf.fit(data_train, target_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
print('Baseline Tree Classifier train accuracy:', str(round(BL_tree_clf.score(data_train, target_train)*100,2))+'%','\nBaseline Tree Classifier train test accuracy:',str(round(BL_tree_clf.score(data_test, target_test)*100,2))+'%',sep='\n')
# Out:
# Baseline Tree Classifier train accuracy:
# 9.93%
#
# Baseline Tree Classifier train test accuracy:
# 6.1%

# %% [markdown]
# #### Confusion Matrix of Baseline Tree Classifier:

# %%
pred = BL_tree_clf.predict(data_test)
print('\nConfusion Matrix')
print('----------------')
pd.crosstab(target_test, pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Confusion Matrix
# ----------------
# Predicted                  Astoria  Battery Park  Chelsea  Clinton  \
# True
# Astoria                          1             0        0        1
# Battery Park                     0             0        0        1
# Bedford Stuyvesant               0             0        0        0
# Boerum Hill                      0             0        0        1
# Brooklyn Heights                 0             0        0        0
# Carroll Gardens                  0             0        0        2
# Central Park                     0             0        0        0
# Chelsea                          0             1        0        5
# Chinatown                        0             0        0        2
# Clinton                          0             0        2        3
# Clinton Hill                     0             0        0        0
# Cobble Hill                      0             0        0        0
# Columbus Circle                  0             0        0        2
# Crown Heights                    0             0        0        1
# DUMBO                            0             0        0        0
# Downtown                         0             0        0        0
# East Harlem                      0             0        0        0
# East Village                     0             0        2        5
# Financial District               0             0        0        2
# Flatiron District                1             0        0        2
# Fort Greene                      0             0        0        0
# Garment District                 0             0        0        3
# Gowanus                          0             0        0        1
# Gramercy                         0             0        0        1
# Greenpoint                       0             0        0        0
# Greenwich Village                0             0        0        4
# Harlem                           0             0        0        1
# Hunters Point                    0             0        0        0
# Little Italy                     0             0        0        1
# Lower East Side                  0             0        1        3
# Midtown                          0             0        0        2
# Morningside Heights              0             0        0        0
# Murray Hill                      0             0        0        2
# Navy Yard                        1             0        0        0
# NoHo                             0             0        0        0
# Park Slope                       0             0        0        3
# Prospect Heights                 0             0        0        1
# Prospect Lefferts Gardens        0             0        0        0
# Red Hook                         0             0        0        0
# SoHo                             0             0        0        1
# Stuyvesant Town                  0             0        1        1
# Sutton Place                     0             0        0        0
# Tribeca                          0             0        0        1
# Tudor City                       0             0        0        1
# Turtle Bay                       0             0        0        0
# Upper East Side                  0             0        0        3
# Upper West Side                  0             0        0        2
# West Village                     0             0        1        1
# Williamsburg                     0             0        1        4
# All                              3             1        8       63
#
# Predicted                  East Village  Flatiron District  Garment District  \
# True
# Astoria                               0                  0                 0
# Battery Park                          0                  0                 0
# Bedford Stuyvesant                    0                  0                 0
# Boerum Hill                           0                  0                 1
# Brooklyn Heights                      0                  0                 0
# Carroll Gardens                       1                  0                 2
# Central Park                          0                  0                 0
# Chelsea                               4                  0                 1
# Chinatown                             1                  0                 0
# Clinton                               4                  0                 2
# Clinton Hill                          0                  0                 0
# Cobble Hill                           0                  0                 0
# Columbus Circle                       0                  0                 0
# Crown Heights                         0                  0                 0
# DUMBO                                 0                  0                 1
# Downtown                              0                  0                 0
# East Harlem                           1                  0                 0
# East Village                          4                  0                 3
# Financial District                    0                  1                 0
# Flatiron District                     3                  0                 0
# Fort Greene                           1                  0                 0
# Garment District                      2                  0                 3
# Gowanus                               0                  0                 0
# Gramercy                              9                  0                 1
# Greenpoint                            0                  0                 0
# Greenwich Village                     4                  0                 2
# Harlem                                1                  0                 0
# Hunters Point                         0                  0                 0
# Little Italy                          1                  0                 0
# Lower East Side                       1                  0                 1
# Midtown                               4                  0                 0
# Morningside Heights                   0                  0                 0
# Murray Hill                           1                  0                 0
# Navy Yard                             0                  0                 0
# NoHo                                  0                  0                 0
# Park Slope                            1                  0                 0
# Prospect Heights                      0                  0                 0
# Prospect Lefferts Gardens             0                  0                 0
# Red Hook                              0                  0                 0
# SoHo                                  0                  0                 0
# Stuyvesant Town                       1                  0                 1
# Sutton Place                          0                  0                 0
# Tribeca                               0                  0                 2
# Tudor City                            1                  0                 0
# Turtle Bay                            2                  0                 0
# Upper East Side                       1                  1                 0
# Upper West Side                       1                  1                 1
# West Village                          1                  0                 1
# Williamsburg                          1                  0                 0
# All                                  51                  3                22
#
# Predicted                  Gramercy  Greenwich Village  Lower East Side  \
# True
# Astoria                           0                  1                0
# Battery Park                      0                  0                1
# Bedford Stuyvesant                0                  0                0
# Boerum Hill                       0                  0                0
# Brooklyn Heights                  0                  0                1
# Carroll Gardens                   0                  0                1
# Central Park                      0                  1                1
# Chelsea                           1                  3                4
# Chinatown                         0                  0                0
# Clinton                           0                  3                2
# Clinton Hill                      0                  1                1
# Cobble Hill                       0                  0                0
# Columbus Circle                   0                  1                2
# Crown Heights                     0                  1                0
# DUMBO                             0                  0                0
# Downtown                          0                  0                0
# East Harlem                       0                  0                0
# East Village                      0                  3                1
# Financial District                0                  1                0
# Flatiron District                 0                  0                0
# Fort Greene                       0                  4                1
# Garment District                  0                  3                3
# Gowanus                           0                  0                0
# Gramercy                          0                  2                0
# Greenpoint                        0                  2                0
# Greenwich Village                 0                  4                5
# Harlem                            0                  2                0
# Hunters Point                     0                  0                0
# Little Italy                      0                  0                1
# Lower East Side                   0                  0                1
# Midtown                           0                  2                2
# Morningside Heights               0                  0                0
# Murray Hill                       0                  1                1
# Navy Yard                         0                  0                0
# NoHo                              0                  1                0
# Park Slope                        0                  1                0
# Prospect Heights                  0                  0                0
# Prospect Lefferts Gardens         0                  0                1
# Red Hook                          0                  0                0
# SoHo                              0                  0                0
# Stuyvesant Town                   0                  1                0
# Sutton Place                      0                  0                0
# Tribeca                           0                  1                0
# Tudor City                        0                  0                0
# Turtle Bay                        0                  0                1
# Upper East Side                   0                  2                0
# Upper West Side                   0                  4                3
# West Village                      0                  0                0
# Williamsburg                      0                  0                1
# All                               1                 45               34
#
# Predicted                  Midtown  Park Slope  Upper West Side  Williamsburg  \
# True
# Astoria                          2           1                1             2
# Battery Park                     0           1                4             2
# Bedford Stuyvesant               0           0                3             0
# Boerum Hill                      0           0                1             4
# Brooklyn Heights                 0           0                0             0
# Carroll Gardens                  3           0                7             0
# Central Park                     5           0                5             0
# Chelsea                          7           0               18             9
# Chinatown                        1           0                2             3
# Clinton                          6           1               22             7
# Clinton Hill                     1           0                4             0
# Cobble Hill                      0           0                8             4
# Columbus Circle                  2           0                8             9
# Crown Heights                    0           0                2             1
# DUMBO                            1           0                3             0
# Downtown                         3           0                5             3
# East Harlem                      2           0                4             0
# East Village                    18           1               17            15
# Financial District               4           1                4             3
# Flatiron District                9           0               20             4
# Fort Greene                      1           0               11             3
# Garment District                 5           0               29             5
# Gowanus                          2           0                2             1
# Gramercy                         8           0               13             8
# Greenpoint                       2           0                3             3
# Greenwich Village                7           1               19            12
# Harlem                           1           0                1             1
# Hunters Point                    1           0                3             1
# Little Italy                     1           0                2             1
# Lower East Side                 15           0               21            13
# Midtown                          7           0               19            10
# Morningside Heights              0           0                1             0
# Murray Hill                      2           0               18             9
# Navy Yard                        0           0                3             1
# NoHo                             0           0                3             2
# Park Slope                       4           1               15             4
# Prospect Heights                 0           0                0             1
# Prospect Lefferts Gardens        0           0                0             1
# Red Hook                         0           0                1             2
# SoHo                             1           0                1             2
# Stuyvesant Town                  5           0               10             4
# Sutton Place                     0           0                1             0
# Tribeca                          7           0                8             5
# Tudor City                       1           0                4             1
# Turtle Bay                       2           0                1             0
# Upper East Side                 16           1               18             6
# Upper West Side                 14           0               26             7
# West Village                     3           0               15             5
# Williamsburg                     5           1               15            11
# All                            174           9              401           185
#
# Predicted                   All
# True
# Astoria                       9
# Battery Park                  9
# Bedford Stuyvesant            3
# Boerum Hill                   7
# Brooklyn Heights              1
# Carroll Gardens              16
# Central Park                 12
# Chelsea                      53
# Chinatown                     9
# Clinton                      52
# Clinton Hill                  7
# Cobble Hill                  12
# Columbus Circle              24
# Crown Heights                 5
# DUMBO                         5
# Downtown                     11
# East Harlem                   7
# East Village                 69
# Financial District           16
# Flatiron District            39
# Fort Greene                  21
# Garment District             53
# Gowanus                       6
# Gramercy                     42
# Greenpoint                   10
# Greenwich Village            58
# Harlem                        7
# Hunters Point                 5
# Little Italy                  7
# Lower East Side              56
# Midtown                      46
# Morningside Heights           1
# Murray Hill                  34
# Navy Yard                     5
# NoHo                          6
# Park Slope                   29
# Prospect Heights              2
# Prospect Lefferts Gardens     2
# Red Hook                      3
# SoHo                          5
# Stuyvesant Town              24
# Sutton Place                  1
# Tribeca                      24
# Tudor City                    8
# Turtle Bay                    6
# Upper East Side              48
# Upper West Side              59
# West Village                 27
# Williamsburg                 39
# All                        1000

# %%
forest_bl = RandomForestClassifier(n_estimators=100, max_depth= 5)
forest_bl.fit(data_train, target_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
print('Baseline random forest accuracy:', str(round(forest_bl.score(data_train, target_train)*100,2))+'%',
      '\nBaseline random forest test accuracy:',str(round(forest_bl.score(data_test, target_test)*100,2))+'%',sep='\n')
# Out:
# Baseline random forest accuracy:
# 16.5%
#
# Baseline random forest test accuracy:
# 7.5%

# %% [markdown]
# __Baseline Random Forest for DataFrame with Start Neighborhood__

# %%
forest_bl_sn = RandomForestClassifier(n_estimators=100, max_depth= 5)
forest_bl_sn.fit(data_train_sn, target_train_sn)
# data_train_sn, data_test_sn, target_train_sn, target_test_sn
print('Baseline random forest accuracy:', str(round(forest_bl_sn.score(data_train_sn, target_train_sn)*100,2))+'%',
      '\nBaseline random forest test accuracy:',str(round(forest_bl_sn.score(data_test_sn, target_test_sn)*100,2))+'%',sep='\n')
# Out:
# Baseline random forest accuracy:
# 18.95%
#
# Baseline random forest test accuracy:
# 6.7%

# %%
rf_param_grid_2 = {
    'n_estimators': [50,100,150,200],
    'criterion': ['entropy'],
    'max_depth': [None, 2, 5],
    'min_samples_split': [2, 5, 12],
    'min_samples_leaf': [1,2]
}

# %%
rf_grid_search_sn = GridSearchCV(forest_bl_sn, rf_param_grid_2, cv=3, return_train_score=True)
rf_grid_search_sn.fit(data_snhbr,target_snhbr)

rf_training_score_sn = np.mean(rf_grid_search_sn.cv_results_['mean_train_score'])
rf_testing_score_sn = rf_grid_search_sn.score(data_snhbr,target_snhbr)

print("Mean Training Score: {:.4}%".format(rf_training_score_sn * 100))
print("Mean Testing Score: {:.4}%".format(rf_testing_score_sn * 100))
print("Best Parameter Combination Found During Grid Search:")
rf_grid_search.best_params_
# Out:
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=3.
#   % (min_groups, self.n_splits)), Warning)
# Mean Training Score: 40.68%
# Mean Testing Score: 14.76%
# Best Parameter Combination Found During Grid Search:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-732e5aaf491d> in <module>()
#       8 print("Mean Testing Score: {:.4}%".format(rf_testing_score_sn * 100))
#       9 print("Best Parameter Combination Found During Grid Search:")
# ---> 10 rf_grid_search.best_params_
#
# NameError: name 'rf_grid_search' is not defined

# %%
rf_grid_search_sn.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 5,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'n_estimators': 50}

# %%
# data_train_sn, data_test_sn, target_train_sn, target_test_sn
rf_grid_search_sn_new = RandomForestClassifier(criterion='entropy',max_depth=5,
                                               min_samples_leaf=2,min_samples_split=2,n_estimators=50)
rf_grid_search_sn_new.fit(data_train_sn,target_train_sn)
y_pred_test = rf_grid_search_sn_new.predict(data_test_sn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eb0eb3d8f5ac> in <module>()
#       1 # data_train_sn, data_test_sn, target_train_sn, target_test_sn
# ----> 2 rf_grid_search_sn_new = RandomForestClassifier(criterion='entropy',max_depth=5,
#       3                                                min_samples_leaf=2,min_samples_split=2,n_estimators=50)
#       4 rf_grid_search_sn_new.fit(data_train_sn,target_train_sn)
#       5 y_pred_test = rf_grid_search_sn_new.predict(data_test_sn)
#
# NameError: name 'RandomForestClassifier' is not defined

# %%
show_cf(target_test_sn, y_pred_test, class_names=list(set(target_train_sn)), model_name='Random Forest with Start and Stop Neighborhoods')

# %%
def show_cf(y_true, y_pred, class_names=None, model_name=None):
    plt.figure(figsize=(20,12))
    cf = confusion_matrix(y_true, y_pred)
    plt.imshow(cf, cmap=plt.cm.Blues)
    
    if model_name:
        plt.title("Confusion Matrix: {}".format(model_name))
    else:
        plt.title("Confusion Matrix")
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    
    class_names = set(y_true)
    tick_marks = np.arange(len(class_names))
    if class_names:
        plt.xticks(tick_marks, class_names)
        plt.yticks(tick_marks, class_names)
    
    thresh = cf.max() / 2.
    
    for i, j in itertools.product(range(cf.shape[0]), range(cf.shape[1])):
        plt.text(j, i, cf[i, j], horizontalalignment='center', color='white' if cf[i, j] > thresh else 'black')
    plt.xticks(rotation=90)
    plt.colorbar()

# %% [markdown]
# ### XGBoost

# %% [markdown]
# Baseline for XGBoost and our data with the start neighborhoods

# %%
# data_snhbr,target_snhbr
# data_train_sn, data_test_sn, target_train_sn, target_test_sn
xgb_clf = xgb.XGBClassifier()
xgb_clf.fit(data_train_sn, target_train_sn)
training_preds = xgb_clf.predict(data_train_sn)
val_preds = xgb_clf.predict(data_test_sn)
training_accuracy = accuracy_score(target_train_sn,training_preds)
val_accuracy = accuracy_score(target_test_sn,val_preds)

print("Training Accuracy: {:.4}%".format(training_accuracy * 100))
print("Validation accuracy: {:.4}%".format(val_accuracy * 100))
# Out:
# Training Accuracy: 26.12%
# Validation accuracy: 6.4%

# %% [markdown]
# __Create a parameter grid dictionary__

# %%
param_grid = {
    "learning_rate": [0.5, 0.7, 0.1],
    'max_depth': [2, 3, 4],
    'min_child_weight': [4, 5],
    'n_estimators': [300, 400, 500],
}

# %% [markdown]
# __Use GridSearch to find the best pararmeters for our model__

# %%
# data_snhbr,target_snhbr
# data_train_sn, data_test_sn, target_train_sn, target_test_sn

grid_xgb_clf = GridSearchCV(xgb_clf, param_grid, scoring='accuracy',n_jobs=1,cv=None)
grid_xgb_clf.fit(data_train_sn, target_train_sn)

best_parameters = grid_xgb_clf.best_params_

print("Grid Search found the following optimal parameters: ")
for param_name in sorted(best_parameters.keys()):
    print("%s: %r" % (param_name, best_parameters[param_name]))

training_preds = grid_xgb_clf.predict(data_train_sn)
val_preds = grid_xgb_clf.predict(data_test_sn)
training_accuracy = accuracy_score(target_train_sn,training_preds)
val_accuracy = accuracy_score(target_test_sn,val_preds)

print("")
print("Training Accuracy: {:.4}%".format(training_accuracy * 100))
print("Validation accuracy: {:.4}%".format(val_accuracy * 100))
# Out:
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=3.
#   % (min_groups, self.n_splits)), Warning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-7648c7663746> in <module>()
#       3
#       4 grid_xgb_clf = GridSearchCV(xgb_clf, param_grid, scoring='accuracy',n_jobs=1,cv=None)
# ----> 5 grid_xgb_clf.fit(data_train_sn, target_train_sn)
#       6
#       7 best_parameters = grid_xgb_clf.best_params_
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     720                 return results_container[0]
#     721
# --> 722             self._run_search(evaluate_candidates)
#     723
#     724         results = results_container[0]
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1189     def _run_search(self, evaluate_candidates):
#    1190         """Search all candidates in param_grid"""
# -> 1191         evaluate_candidates(ParameterGrid(self.param_grid))
#    1192
#    1193
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     709                                for parameters, (train, test)
#     710                                in product(candidate_params,
# --> 711                                           cv.split(X, y, groups)))
#     712
#     713                 all_candidate_params.extend(candidate_params)
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     918                 self._iterating = self._original_iterator is not None
#     919
# --> 920             while self.dispatch_one_batch(iterator):
#     921                 pass
#     922
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     526             estimator.fit(X_train, **fit_params)
#     527         else:
# --> 528             estimator.fit(X_train, y_train, **fit_params)
#     529
#     530     except Exception as e:
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set)
#     589                               early_stopping_rounds=early_stopping_rounds,
#     590                               evals_result=evals_result, obj=obj, feval=feval,
# --> 591                               verbose_eval=verbose, xgb_model=None)
#     592
#     593         self.objective = xgb_options["objective"]
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     208                            evals=evals,
#     209                            obj=obj, feval=feval,
# --> 210                            xgb_model=xgb_model, callbacks=callbacks)
#     211
#     212
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# /Users/elenasm7/anaconda/lib/python3.6/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1019         if fobj is None:
#    1020             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1021                                                     dtrain.handle))
#    1022         else:
#    1023             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
# data_snhbr,target_snhbr
# data_train_sn, data_test_sn, target_train_sn, target_test_sn
xgb_clf = xgb.XGBClassifier(learning_rate=0.5,max_depth=3,min_child_weight=5,n_estimators=300)
xgb_clf.fit(data_train_sn, target_train_sn)
training_preds = xgb_clf.predict(data_train_sn)
val_preds = xgb_clf.predict(data_test_sn)
training_accuracy = accuracy_score(target_train_sn,training_preds)
val_accuracy = accuracy_score(target_test_sn,val_preds)

print("Training Accuracy: {:.4}%".format(training_accuracy * 100))
print("Validation accuracy: {:.4}%".format(val_accuracy * 100))

# "learning_rate": [0.5, 0.7, 0.1],
#     'max_depth': [2, 3, 4],
#     'min_child_weight': [4, 5],
#     'n_estimators': [300, 400, 500]
# Out:
# Training Accuracy: 74.72%
# Validation accuracy: 3.8%

# %%
xgb_clf = xgb.XGBClassifier(learning_rate=0.5,max_depth=2,min_child_weight=5,n_estimators=150)
xgb_clf.fit(data_train_sn, target_train_sn)
training_preds = xgb_clf.predict(data_train_sn)
val_preds = xgb_clf.predict(data_test_sn)
training_accuracy = accuracy_score(target_train_sn,training_preds)
val_accuracy = accuracy_score(target_test_sn,val_preds)

print("Training Accuracy: {:.4}%".format(training_accuracy * 100))
print("Validation accuracy: {:.4}%".format(val_accuracy * 100))
# Out:
# Training Accuracy: 31.5%
# Validation accuracy: 5.0%

# %%
xgb_clf = xgb.XGBClassifier(learning_rate=0.5,max_depth=2,min_child_weight=2,n_estimators=100)
xgb_clf.fit(data_train_sn, target_train_sn)
training_preds = xgb_clf.predict(data_train_sn)
val_preds = xgb_clf.predict(data_test_sn)
training_accuracy = accuracy_score(target_train_sn,training_preds)
val_accuracy = accuracy_score(target_test_sn,val_preds)

print("Training Accuracy: {:.4}%".format(training_accuracy * 100))
print("Validation accuracy: {:.4}%".format(val_accuracy * 100))
# Out:
# Training Accuracy: 32.62%
# Validation accuracy: 6.1%

# %%
xgb_clf = xgb.XGBClassifier(learning_rate=0.3,max_depth=2,min_child_weight=2,n_estimators=100)
xgb_clf.fit(data_train_sn, target_train_sn)
training_preds = xgb_clf.predict(data_train_sn)
val_preds = xgb_clf.predict(data_test_sn)
training_accuracy = accuracy_score(target_train_sn,training_preds)
val_accuracy = accuracy_score(target_test_sn,val_preds)

print("Training Accuracy: {:.4}%".format(training_accuracy * 100))
print("Validation accuracy: {:.4}%".format(val_accuracy * 100))
# Out:
# Training Accuracy: 25.25%
# Validation accuracy: 7.0%

# %%
xgb_clf = xgb.XGBClassifier(learning_rate=0.2,max_depth=3,min_child_weight=2,n_estimators=100)
xgb_clf.fit(data_train_sn, target_train_sn)
training_preds = xgb_clf.predict(data_train_sn)
val_preds = xgb_clf.predict(data_test_sn)
training_accuracy = accuracy_score(target_train_sn,training_preds)
val_accuracy = accuracy_score(target_test_sn,val_preds)

print("Training Accuracy: {:.4}%".format(training_accuracy * 100))
print("Validation accuracy: {:.4}%".format(val_accuracy * 100))
# Out:
# Training Accuracy: 34.55%
# Validation accuracy: 5.6%

# %%
xgb_clf

# %%
'criterion': 'entropy',
 'max_depth': 5,
 'min_samples_leaf': 2,
 'min_samples_split': 2,
 'n_estimators': 50

# %%
# data_snhbr,target_snhbr
# data_train_sn, data_test_sn, target_train_sn, target_test_sn
xgb_clf_bt = xgb.XGBClassifier(learning_rate=0.4,max_depth=5,min_child_weight=3,n_estimators=50)
xgb_clf_bt.fit(data_train_sn, target_train_sn)
training_preds = xgb_clf_bt.predict(data_train_sn)
val_preds = xgb_clf_bt.predict(data_test_sn)
training_accuracy = accuracy_score(target_train_sn,training_preds)
val_accuracy = accuracy_score(target_test_sn,val_preds)

print("Training Accuracy: {:.4}%".format(training_accuracy * 100))
print("Validation accuracy: {:.4}%".format(val_accuracy * 100))
# Out:
# Training Accuracy: 58.98%
# Validation accuracy: 5.4%
